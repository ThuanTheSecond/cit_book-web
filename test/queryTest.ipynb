# %%
from django_for_jupyter import init_django
init_django()

# %%
import pandas as pd

# Thay 'ten_file_cua_ban.csv' bằng đường dẫn thực tế tới file CSV

try:
    # Đọc file CSV
    df = pd.read_csv(r'C:\Users\thait\Downloads\exact_matched_books (2).csv')

    # Tạo một từ điển để lưu độ dài lớn nhất của mỗi cột
    max_lengths = {}

    # Duyệt qua từng cột
    for col in df.columns:
        # Chuyển cột sang kiểu chuỗi, tính độ dài và tìm max
        # fillna('') để xử lý các ô trống (NaN) - coi chúng có độ dài 0
        max_len = df[col].astype(str).fillna('').map(len).max()
        max_lengths[col] = max_len

    # In kết quả
    print("Chiều dài lớn nhất của dữ liệu trong mỗi cột:")
    for col, length in max_lengths.items():
        print(f"- Cột '{col}': {length}")

except FileNotFoundError:
    print(f"Lỗi: Không tìm thấy file tại đường dẫn '{file_path}'")
except Exception as e:
    print(f"Đã xảy ra lỗi: {e}")
# Out:
# Chiều dài lớn nhất của dữ liệu trong mỗi cột:
# - Cột 'book_id': 4
# - Cột 'book_title': 146
# - Cột 'book_author': 240
# - Cột 'book_publish': 67
# - Cột 'parent_asin': 10
# - Cột 'average_rating': 3
# - Cột 'rating_number': 4
# - Cột 'img_large': 87
# - Cột 'isbn_10': 11
# - Cột 'isbn_13': 13

# %%
import pandas as pd
import requests
from io import BytesIO
from django.core.files.base import ContentFile
from home.models import Book

# Đọc file exact_matched_books.csv
books_df = pd.read_csv(r'C:\Users\thait\Downloads\exact_matched_books (2).csv')

# Hàm tải hình ảnh từ URL và lưu vào ImageField
def download_image(url, book_id):
    if not url or not isinstance(url, str):  # Kiểm tra URL rỗng hoặc không phải chuỗi
        return None
    try:
        response = requests.get(url, timeout=5)
        if response.status_code == 200:
            file_name = f'book_{book_id}.jpg'
            image_content = ContentFile(response.content)
            return (file_name, image_content)
        return None
    except Exception as e:
        print(f"Lỗi khi tải hình ảnh từ URL {url}: {e}")
        return None

# Hàm chuyển isbn_13 thành số nguyên cho book_MFN
def isbn_to_mfn(isbn_13):
    if not isbn_13 or not isinstance(isbn_13, str):  # Kiểm tra isbn_13 rỗng hoặc không phải chuỗi
        return 0
    # Loại bỏ ký tự không phải số
    digits = ''.join(filter(str.isdigit, isbn_13))
    return int(digits) if digits else 0

# Insert dữ liệu vào bảng Book
for _, row in books_df.iterrows():
    # Tải hình ảnh từ URL
    image_data = download_image(row['img_large'], row['book_id'])
    
    # Tạo đối tượng Book
    book = Book(
        book_id=row['book_id'],
        book_title=row['book_title'],
        book_author=row['book_author'],
        book_position='Unknown',  # Giá trị mặc định
        book_MFN=isbn_to_mfn(row['isbn_13']),  # Chuyển isbn_13 thành số nguyên
        book_publish=row['book_publish'] if row['book_publish'] else 'No information',
        isbn_10=row['isbn_10'] if row['isbn_10'] else '',
        isbn_13=row['isbn_13'] if row['isbn_13'] else '',
    )
    
    # Nếu tải được hình ảnh, lưu vào book_image
    if image_data:
        file_name, image_content = image_data
        book.bookImage.save(file_name, image_content, save=True)
    # Nếu không tải được, book_image sẽ tự động dùng giá trị mặc định (imgBooks/nothumb.jpg)
    
    # Lưu đối tượng Book vào database
    book.save()

print("Đã nhập dữ liệu thành công vào bảng Book!")

# %%
# Script chạy trên máy local để xử lý dataset Amazon-Reviews-2023 (raw_review_Books)

# Bước 1: Cài đặt các thư viện cần thiết
# Chạy các lệnh sau trong terminal để cài đặt:
# pip install pandas datasets tenacity

# Bước 2: Import các thư viện
import pandas as pd
from datasets import load_dataset
from datetime import datetime
import json
import time
import os
from tenacity import retry, wait_exponential, stop_after_attempt, retry_if_exception_type
from requests.exceptions import HTTPError

# Bước 3: Thiết lập HF_TOKEN
# Cách 1: Đặt HF_TOKEN trực tiếp trong code (không khuyến nghị vì lý do bảo mật)
# HF_TOKEN = "hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"  # Thay bằng token của bạn

# Cách 2: Đặt HF_TOKEN qua biến môi trường (khuyến nghị)
# Trên Windows: set HF_TOKEN=hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Trên macOS/Linux: export HF_TOKEN=hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
HF_TOKEN = "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"
if not HF_TOKEN:
    raise ValueError("HF_TOKEN không được tìm thấy. Vui lòng đặt HF_TOKEN trong biến môi trường hoặc trong code.")

# Đường dẫn file (thay đổi theo máy local của bạn)
EXACT_MATCHED_BOOKS_PATH = r"C:\Users\thait\LABS\NC\cit-meta\exact_matched_books.csv"
AMAZON_USER_PATH = r"C:\Users\thait\LABS\NC\cit-meta\AmazonUser.csv"
AMAZON_RATING_PATH = r"C:\Users\thait\LABS\NC\cit-meta\AmazonRating.csv"
PRETRAIN_DATA_PATH = r"C:\Users\thait\LABS\NC\cit-meta\PretrainData.csv"
CHECKPOINT_PATH = r"C:\Users\thait\LABS\NC\cit-meta\checkpoint.json"

# Tạo thư mục nếu chưa tồn tại
os.makedirs(os.path.dirname(EXACT_MATCHED_BOOKS_PATH), exist_ok=True)

# Đọc exact_matched_books.csv và tạo tập hợp parent_asin
print("Đang đọc file exact_matched_books.csv...")
exact_matched_books = pd.read_csv(EXACT_MATCHED_BOOKS_PATH)
asin_to_book_id = dict(zip(exact_matched_books['parent_asin'], exact_matched_books['book_id']))
parent_asins = set(asin_to_book_id.keys())
print(f"Đã đọc {len(parent_asins)} parent_asin")

# Tải dataset với streaming và retry
@retry(
    retry=retry_if_exception_type(HTTPError),
    wait=wait_exponential(multiplier=1, min=4, max=120),  # Chờ tối đa 120s
    stop=stop_after_attempt(10),  # Thử lại tối đa 10 lần
    before=lambda retry_state: print(f"Thử lại lần {retry_state.attempt_number} sau lỗi 429..."),
    after=lambda retry_state: print(f"Thử lại thành công sau {retry_state.attempt_number} lần")
)
def load_dataset_with_retry():
    print("Đang tải dataset Amazon-Reviews-2023 (raw_review_Books) với streaming...")
    return load_dataset(
        "McAuley-Lab/Amazon-Reviews-2023",
        "raw_review_Books",
        trust_remote_code=True,
        streaming=True,
        token=HF_TOKEN  # Sử dụng HF_TOKEN để tăng giới hạn rate limit
    )

start_time = time.time()
try:
    dataset = load_dataset_with_retry()
except Exception as e:
    print(f"Lỗi không thể khắc phục khi tải dataset: {str(e)}")
    raise

# Khởi tạo checkpoint
checkpoint = {
    'processed_reviews': 0,
    'user_mapping': {},
    'next_user_id': 1,
    'last_chunk_processed': 0
}
try:
    with open(CHECKPOINT_PATH, 'r') as f:
        checkpoint = json.load(f)
    print(f"Đã khôi phục checkpoint: {checkpoint['processed_reviews']} reviews đã được xử lý trước đó")
except FileNotFoundError:
    print("Không tìm thấy checkpoint, bắt đầu từ đầu")

user_mapping = checkpoint['user_mapping']
next_user_id = checkpoint['next_user_id']
processed_reviews = checkpoint['processed_reviews']
last_chunk_processed = checkpoint['last_chunk_processed']

# Tạo file CSV nếu chưa tồn tại hoặc append mode
def initialize_csv_files():
    if last_chunk_processed == 0:
        pd.DataFrame(columns=['id', 'amazon_user_id']).to_csv(AMAZON_USER_PATH, index=False)
        pd.DataFrame(columns=['amazon_user_id', 'book_id', 'rating', 'timestamp']).to_csv(AMAZON_RATING_PATH, index=False)
        pd.DataFrame(columns=['user_id', 'book_id', 'rating']).to_csv(PRETRAIN_DATA_PATH, index=False)

initialize_csv_files()

# Xử lý dữ liệu theo chunks
CHUNK_SIZE = 10000
chunk_reviews = []
iterator = iter(dataset['full'])
chunk_count = 0
total_reviews_processed = 0

# Bỏ qua các chunk đã xử lý
for _ in range(last_chunk_processed * CHUNK_SIZE):
    try:
        next(iterator)
        total_reviews_processed += 1
    except StopIteration:
        break

while True:
    start_chunk_time = time.time()
    chunk_reviews = []
    try:
        for _ in range(CHUNK_SIZE):
            review = next(iterator)
            if review['parent_asin'] in parent_asins:
                chunk_reviews.append(review)
            total_reviews_processed += 1
    except StopIteration:
        if not chunk_reviews:
            break

    chunk_count += 1
    print(f"\nBắt đầu xử lý chunk {chunk_count} (tổng số reviews đã duyệt: {total_reviews_processed})...")

    if not chunk_reviews:
        print("Chunk rỗng, tiếp tục...")
        continue

    # Chuyển chunk thành DataFrame để xử lý nhanh hơn
    chunk_df = pd.DataFrame(chunk_reviews)
    chunk_df['book_id'] = chunk_df['parent_asin'].map(asin_to_book_id)
    chunk_df['rating'] = chunk_df['rating'].astype(float)
    chunk_df['timestamp'] = chunk_df['timestamp'].apply(lambda x: datetime.fromtimestamp(x / 1000.0).strftime('%Y-%m-%d %H:%M:%S.%f'))

    # Lọc các rating không hợp lệ
    invalid_ratings = chunk_df[~chunk_df['rating'].between(1, 5)]
    for _, row in invalid_ratings.iterrows():
        print(f"Cảnh báo: Rating không hợp lệ ({row['rating']}) cho user {row['user_id']}, book_id {row['book_id']}, bỏ qua...")
    chunk_df = chunk_df[chunk_df['rating'].between(1, 5)]

    # Xử lý người dùng mới
    new_users = chunk_df[~chunk_df['user_id'].isin(user_mapping.keys())]['user_id'].unique()
    new_users_df = pd.DataFrame({
        'id': range(next_user_id, next_user_id + len(new_users)),
        'amazon_user_id': new_users
    })
    if not new_users_df.empty:
        new_user_mapping = dict(zip(new_users, new_users_df['id']))
        user_mapping.update(new_user_mapping)
        next_user_id += len(new_users)
        # Append vào file CSV
        new_users_df.to_csv(AMAZON_USER_PATH, mode='a', header=False, index=False)

    # Tạo dữ liệu amazon_ratings và pretrain_data
    chunk_df['user_id_mapped'] = chunk_df['user_id'].map(user_mapping)
    amazon_ratings_df = chunk_df[['user_id', 'book_id', 'rating', 'timestamp']].copy()
    amazon_ratings_df.rename(columns={'user_id': 'amazon_user_id'}, inplace=True)
    pretrain_data_df = pd.DataFrame({
        'user_id': chunk_df['user_id_mapped'].apply(lambda x: f"AMZ_{x}"),
        'book_id': chunk_df['book_id'],
        'rating': chunk_df['rating']
    })

    # Append vào file CSV
    amazon_ratings_df.to_csv(AMAZON_RATING_PATH, mode='a', header=False, index=False)
    pretrain_data_df.to_csv(PRETRAIN_DATA_PATH, mode='a', header=False, index=False)

    processed_reviews += len(chunk_df)
    print(f"Đã xử lý chunk {chunk_count}: {len(chunk_df)} đánh giá hợp lệ, {len(new_users)} người dùng mới được thêm")
    print(f"Tổng số reviews đã xử lý: {processed_reviews}")
    print(f"Tổng số người dùng hiện tại: {len(user_mapping)}")
    print(f"Thời gian xử lý chunk: {time.time() - start_chunk_time:.2f} giây")

    # Cập nhật checkpoint
    checkpoint['processed_reviews'] = processed_reviews
    checkpoint['user_mapping'] = user_mapping
    checkpoint['next_user_id'] = next_user_id
    checkpoint['last_chunk_processed'] = chunk_count
    with open(CHECKPOINT_PATH, 'w') as f:
        json.dump(checkpoint, f)
    print(f"Đã lưu checkpoint tại {CHECKPOINT_PATH}")

    # Thêm thời gian chờ để tránh lỗi 429
    print("Chờ 10 giây trước khi xử lý chunk tiếp theo...")
    time.sleep(10)

# Xử lý chunk cuối (nếu có)
if chunk_reviews:
    start_chunk_time = time.time()
    chunk_count += 1
    print(f"\nBắt đầu xử lý chunk cuối {chunk_count} (tổng số reviews đã duyệt: {total_reviews_processed})...")

    chunk_df = pd.DataFrame(chunk_reviews)
    chunk_df['book_id'] = chunk_df['parent_asin'].map(asin_to_book_id)
    chunk_df['rating'] = chunk_df['rating'].astype(float)
    chunk_df['timestamp'] = chunk_df['timestamp'].apply(lambda x: datetime.fromtimestamp(x / 1000.0).strftime('%Y-%m-%d %H:%M:%S.%f'))

    invalid_ratings = chunk_df[~chunk_df['rating'].between(1, 5)]
    for _, row in invalid_ratings.iterrows():
        print(f"Cảnh báo: Rating không hợp lệ ({row['rating']}) cho user {row['user_id']}, book_id {row['book_id']}, bỏ qua...")
    chunk_df = chunk_df[chunk_df['rating'].between(1, 5)]

    new_users = chunk_df[~chunk_df['user_id'].isin(user_mapping.keys())]['user_id'].unique()
    new_users_df = pd.DataFrame({
        'id': range(next_user_id, next_user_id + len(new_users)),
        'amazon_user_id': new_users
    })
    if not new_users_df.empty:
        new_user_mapping = dict(zip(new_users, new_users_df['id']))
        user_mapping.update(new_user_mapping)
        next_user_id += len(new_users)
        new_users_df.to_csv(AMAZON_USER_PATH, mode='a', header=False, index=False)

    chunk_df['user_id_mapped'] = chunk_df['user_id'].map(user_mapping)
    amazon_ratings_df = chunk_df[['user_id', 'book_id', 'rating', 'timestamp']].copy()
    amazon_ratings_df.rename(columns={'user_id': 'amazon_user_id'}, inplace=True)
    pretrain_data_df = pd.DataFrame({
        'user_id': chunk_df['user_id_mapped'].apply(lambda x: f"AMZ_{x}"),
        'book_id': chunk_df['book_id'],
        'rating': chunk_df['rating']
    })

    amazon_ratings_df.to_csv(AMAZON_RATING_PATH, mode='a', header=False, index=False)
    pretrain_data_df.to_csv(PRETRAIN_DATA_PATH, mode='a', header=False, index=False)

    processed_reviews += len(chunk_df)
    print(f"Đã xử lý chunk cuối: {len(chunk_df)} đánh giá hợp lệ, {len(new_users)} người dùng mới được thêm")
    print(f"Tổng số reviews đã xử lý: {processed_reviews}")
    print(f"Tổng số người dùng hiện tại: {len(user_mapping)}")
    print(f"Thời gian xử lý chunk cuối: {time.time() - start_chunk_time:.2f} giây")

    checkpoint['processed_reviews'] = processed_reviews
    checkpoint['user_mapping'] = user_mapping
    checkpoint['next_user_id'] = next_user_id
    checkpoint['last_chunk_processed'] = chunk_count
    with open(CHECKPOINT_PATH, 'w') as f:
        json.dump(checkpoint, f)
    print(f"Đã lưu checkpoint cuối tại {CHECKPOINT_PATH}")

print(f"\nHoàn tất quá trình xử lý! Tổng thời gian: {(time.time() - start_time) / 60:.2f} phút")
# Out:
# Đang đọc file exact_matched_books.csv...
# Đã đọc 204 parent_asin
# Thử lại lần 1 sau lỗi 429...
# Đang tải dataset Amazon-Reviews-2023 (raw_review_Books) với streaming...
# Không tìm thấy checkpoint, bắt đầu từ đầu
#
# Bắt đầu xử lý chunk 1 (tổng số reviews đã duyệt: 10000)...
# Đã xử lý chunk 1: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 1
# Tổng số người dùng hiện tại: 1
# Thời gian xử lý chunk: 2.71 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 2 (tổng số reviews đã duyệt: 20000)...
# Đã xử lý chunk 2: 5 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 6
# Tổng số người dùng hiện tại: 2
# Thời gian xử lý chunk: 1.16 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 3 (tổng số reviews đã duyệt: 30000)...
# Đã xử lý chunk 3: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 7
# Tổng số người dùng hiện tại: 3
# Thời gian xử lý chunk: 1.21 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 4 (tổng số reviews đã duyệt: 40000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 5 (tổng số reviews đã duyệt: 50000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 6 (tổng số reviews đã duyệt: 60000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 7 (tổng số reviews đã duyệt: 70000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 8 (tổng số reviews đã duyệt: 80000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 9 (tổng số reviews đã duyệt: 90000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 10 (tổng số reviews đã duyệt: 100000)...
# Đã xử lý chunk 10: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 9
# Tổng số người dùng hiện tại: 5
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 11 (tổng số reviews đã duyệt: 110000)...
# Đã xử lý chunk 11: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 10
# Tổng số người dùng hiện tại: 6
# Thời gian xử lý chunk: 1.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 12 (tổng số reviews đã duyệt: 120000)...
# Đã xử lý chunk 12: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 12
# Tổng số người dùng hiện tại: 8
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 13 (tổng số reviews đã duyệt: 130000)...
# Đã xử lý chunk 13: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 14
# Tổng số người dùng hiện tại: 10
# Thời gian xử lý chunk: 1.03 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 14 (tổng số reviews đã duyệt: 140000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 15 (tổng số reviews đã duyệt: 150000)...
# Đã xử lý chunk 15: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 16
# Tổng số người dùng hiện tại: 12
# Thời gian xử lý chunk: 1.02 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 16 (tổng số reviews đã duyệt: 160000)...
# Đã xử lý chunk 16: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 17
# Tổng số người dùng hiện tại: 13
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 17 (tổng số reviews đã duyệt: 170000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 18 (tổng số reviews đã duyệt: 180000)...
# Đã xử lý chunk 18: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 18
# Tổng số người dùng hiện tại: 14
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 19 (tổng số reviews đã duyệt: 190000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 20 (tổng số reviews đã duyệt: 200000)...
# Đã xử lý chunk 20: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 19
# Tổng số người dùng hiện tại: 15
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 21 (tổng số reviews đã duyệt: 210000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 22 (tổng số reviews đã duyệt: 220000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 23 (tổng số reviews đã duyệt: 230000)...
# Đã xử lý chunk 23: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 20
# Tổng số người dùng hiện tại: 16
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 24 (tổng số reviews đã duyệt: 240000)...
# Đã xử lý chunk 24: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 21
# Tổng số người dùng hiện tại: 17
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 25 (tổng số reviews đã duyệt: 250000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 26 (tổng số reviews đã duyệt: 260000)...
# Đã xử lý chunk 26: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 22
# Tổng số người dùng hiện tại: 18
# Thời gian xử lý chunk: 1.00 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 27 (tổng số reviews đã duyệt: 270000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 28 (tổng số reviews đã duyệt: 280000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 29 (tổng số reviews đã duyệt: 290000)...
# Đã xử lý chunk 29: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 23
# Tổng số người dùng hiện tại: 19
# Thời gian xử lý chunk: 0.51 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 30 (tổng số reviews đã duyệt: 300000)...
# Đã xử lý chunk 30: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 25
# Tổng số người dùng hiện tại: 21
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 31 (tổng số reviews đã duyệt: 310000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 32 (tổng số reviews đã duyệt: 320000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 33 (tổng số reviews đã duyệt: 330000)...
# Đã xử lý chunk 33: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 27
# Tổng số người dùng hiện tại: 23
# Thời gian xử lý chunk: 0.98 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 34 (tổng số reviews đã duyệt: 340000)...
# Đã xử lý chunk 34: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 28
# Tổng số người dùng hiện tại: 24
# Thời gian xử lý chunk: 0.58 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 35 (tổng số reviews đã duyệt: 350000)...
# Đã xử lý chunk 35: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 29
# Tổng số người dùng hiện tại: 25
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 36 (tổng số reviews đã duyệt: 360000)...
# Đã xử lý chunk 36: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 30
# Tổng số người dùng hiện tại: 26
# Thời gian xử lý chunk: 0.51 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 37 (tổng số reviews đã duyệt: 370000)...
# Đã xử lý chunk 37: 3 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 33
# Tổng số người dùng hiện tại: 27
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 38 (tổng số reviews đã duyệt: 380000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 39 (tổng số reviews đã duyệt: 390000)...
# Đã xử lý chunk 39: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 34
# Tổng số người dùng hiện tại: 28
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 40 (tổng số reviews đã duyệt: 400000)...
# Đã xử lý chunk 40: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 36
# Tổng số người dùng hiện tại: 30
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 41 (tổng số reviews đã duyệt: 410000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 42 (tổng số reviews đã duyệt: 420000)...
# Đã xử lý chunk 42: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 37
# Tổng số người dùng hiện tại: 31
# Thời gian xử lý chunk: 0.78 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 43 (tổng số reviews đã duyệt: 430000)...
# Đã xử lý chunk 43: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 40
# Tổng số người dùng hiện tại: 34
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 44 (tổng số reviews đã duyệt: 440000)...
# Đã xử lý chunk 44: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 41
# Tổng số người dùng hiện tại: 35
# Thời gian xử lý chunk: 0.99 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 45 (tổng số reviews đã duyệt: 450000)...
# Đã xử lý chunk 45: 6 đánh giá hợp lệ, 6 người dùng mới được thêm
# Tổng số reviews đã xử lý: 47
# Tổng số người dùng hiện tại: 41
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 46 (tổng số reviews đã duyệt: 460000)...
# Đã xử lý chunk 46: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 48
# Tổng số người dùng hiện tại: 42
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 47 (tổng số reviews đã duyệt: 470000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 48 (tổng số reviews đã duyệt: 480000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 49 (tổng số reviews đã duyệt: 490000)...
# Đã xử lý chunk 49: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 49
# Tổng số người dùng hiện tại: 43
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 50 (tổng số reviews đã duyệt: 500000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 51 (tổng số reviews đã duyệt: 510000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 52 (tổng số reviews đã duyệt: 520000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 53 (tổng số reviews đã duyệt: 530000)...
# Đã xử lý chunk 53: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 50
# Tổng số người dùng hiện tại: 44
# Thời gian xử lý chunk: 0.51 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 54 (tổng số reviews đã duyệt: 540000)...
# Đã xử lý chunk 54: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 52
# Tổng số người dùng hiện tại: 46
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 55 (tổng số reviews đã duyệt: 550000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 56 (tổng số reviews đã duyệt: 560000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 57 (tổng số reviews đã duyệt: 570000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 58 (tổng số reviews đã duyệt: 580000)...
# Đã xử lý chunk 58: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 55
# Tổng số người dùng hiện tại: 49
# Thời gian xử lý chunk: 1.04 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 59 (tổng số reviews đã duyệt: 590000)...
# Đã xử lý chunk 59: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 57
# Tổng số người dùng hiện tại: 51
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 60 (tổng số reviews đã duyệt: 600000)...
# Đã xử lý chunk 60: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 59
# Tổng số người dùng hiện tại: 53
# Thời gian xử lý chunk: 1.01 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 61 (tổng số reviews đã duyệt: 610000)...
# Đã xử lý chunk 61: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 60
# Tổng số người dùng hiện tại: 54
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 62 (tổng số reviews đã duyệt: 620000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 63 (tổng số reviews đã duyệt: 630000)...
# Đã xử lý chunk 63: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 61
# Tổng số người dùng hiện tại: 55
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 64 (tổng số reviews đã duyệt: 640000)...
# Đã xử lý chunk 64: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 62
# Tổng số người dùng hiện tại: 56
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 65 (tổng số reviews đã duyệt: 650000)...
# Đã xử lý chunk 65: 4 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 66
# Tổng số người dùng hiện tại: 59
# Thời gian xử lý chunk: 0.99 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 66 (tổng số reviews đã duyệt: 660000)...
# Đã xử lý chunk 66: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 67
# Tổng số người dùng hiện tại: 60
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 67 (tổng số reviews đã duyệt: 670000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 68 (tổng số reviews đã duyệt: 680000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 69 (tổng số reviews đã duyệt: 690000)...
# Đã xử lý chunk 69: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 68
# Tổng số người dùng hiện tại: 61
# Thời gian xử lý chunk: 1.02 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 70 (tổng số reviews đã duyệt: 700000)...
# Đã xử lý chunk 70: 4 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 72
# Tổng số người dùng hiện tại: 64
# Thời gian xử lý chunk: 1.01 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 71 (tổng số reviews đã duyệt: 710000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 72 (tổng số reviews đã duyệt: 720000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 73 (tổng số reviews đã duyệt: 730000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 74 (tổng số reviews đã duyệt: 740000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 75 (tổng số reviews đã duyệt: 750000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 76 (tổng số reviews đã duyệt: 760000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 77 (tổng số reviews đã duyệt: 770000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 78 (tổng số reviews đã duyệt: 780000)...
# Đã xử lý chunk 78: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 73
# Tổng số người dùng hiện tại: 65
# Thời gian xử lý chunk: 0.97 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 79 (tổng số reviews đã duyệt: 790000)...
# Đã xử lý chunk 79: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 76
# Tổng số người dùng hiện tại: 68
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 80 (tổng số reviews đã duyệt: 800000)...
# Đã xử lý chunk 80: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 77
# Tổng số người dùng hiện tại: 69
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 81 (tổng số reviews đã duyệt: 810000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 82 (tổng số reviews đã duyệt: 820000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 83 (tổng số reviews đã duyệt: 830000)...
# Đã xử lý chunk 83: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 78
# Tổng số người dùng hiện tại: 70
# Thời gian xử lý chunk: 1.02 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 84 (tổng số reviews đã duyệt: 840000)...
# Đã xử lý chunk 84: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 80
# Tổng số người dùng hiện tại: 72
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 85 (tổng số reviews đã duyệt: 850000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 86 (tổng số reviews đã duyệt: 860000)...
# Đã xử lý chunk 86: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 81
# Tổng số người dùng hiện tại: 73
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 87 (tổng số reviews đã duyệt: 870000)...
# Đã xử lý chunk 87: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 82
# Tổng số người dùng hiện tại: 74
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 88 (tổng số reviews đã duyệt: 880000)...
# Đã xử lý chunk 88: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 83
# Tổng số người dùng hiện tại: 75
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 89 (tổng số reviews đã duyệt: 890000)...
# Đã xử lý chunk 89: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 84
# Tổng số người dùng hiện tại: 76
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 90 (tổng số reviews đã duyệt: 900000)...
# Đã xử lý chunk 90: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 85
# Tổng số người dùng hiện tại: 77
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 91 (tổng số reviews đã duyệt: 910000)...
# Đã xử lý chunk 91: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 88
# Tổng số người dùng hiện tại: 80
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 92 (tổng số reviews đã duyệt: 920000)...
# Đã xử lý chunk 92: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 89
# Tổng số người dùng hiện tại: 81
# Thời gian xử lý chunk: 1.25 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 93 (tổng số reviews đã duyệt: 930000)...
# Đã xử lý chunk 93: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 91
# Tổng số người dùng hiện tại: 83
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 94 (tổng số reviews đã duyệt: 940000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 95 (tổng số reviews đã duyệt: 950000)...
# Đã xử lý chunk 95: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 92
# Tổng số người dùng hiện tại: 84
# Thời gian xử lý chunk: 0.58 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 96 (tổng số reviews đã duyệt: 960000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 97 (tổng số reviews đã duyệt: 970000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 98 (tổng số reviews đã duyệt: 980000)...
# Đã xử lý chunk 98: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 93
# Tổng số người dùng hiện tại: 85
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 99 (tổng số reviews đã duyệt: 990000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 100 (tổng số reviews đã duyệt: 1000000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 101 (tổng số reviews đã duyệt: 1010000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 102 (tổng số reviews đã duyệt: 1020000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 103 (tổng số reviews đã duyệt: 1030000)...
# Đã xử lý chunk 103: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 94
# Tổng số người dùng hiện tại: 86
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 104 (tổng số reviews đã duyệt: 1040000)...
# Đã xử lý chunk 104: 3 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 97
# Tổng số người dùng hiện tại: 88
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 105 (tổng số reviews đã duyệt: 1050000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 106 (tổng số reviews đã duyệt: 1060000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 107 (tổng số reviews đã duyệt: 1070000)...
# Đã xử lý chunk 107: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 101
# Tổng số người dùng hiện tại: 92
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 108 (tổng số reviews đã duyệt: 1080000)...
# Đã xử lý chunk 108: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 102
# Tổng số người dùng hiện tại: 93
# Thời gian xử lý chunk: 1.12 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 109 (tổng số reviews đã duyệt: 1090000)...
# Đã xử lý chunk 109: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 103
# Tổng số người dùng hiện tại: 94
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 110 (tổng số reviews đã duyệt: 1100000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 111 (tổng số reviews đã duyệt: 1110000)...
# Đã xử lý chunk 111: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 105
# Tổng số người dùng hiện tại: 96
# Thời gian xử lý chunk: 0.60 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 112 (tổng số reviews đã duyệt: 1120000)...
# Đã xử lý chunk 112: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 107
# Tổng số người dùng hiện tại: 98
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 113 (tổng số reviews đã duyệt: 1130000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 114 (tổng số reviews đã duyệt: 1140000)...
# Đã xử lý chunk 114: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 108
# Tổng số người dùng hiện tại: 99
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 115 (tổng số reviews đã duyệt: 1150000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 116 (tổng số reviews đã duyệt: 1160000)...
# Đã xử lý chunk 116: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 109
# Tổng số người dùng hiện tại: 100
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 117 (tổng số reviews đã duyệt: 1170000)...
# Đã xử lý chunk 117: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 110
# Tổng số người dùng hiện tại: 101
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 118 (tổng số reviews đã duyệt: 1180000)...
# Đã xử lý chunk 118: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 111
# Tổng số người dùng hiện tại: 102
# Thời gian xử lý chunk: 1.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 119 (tổng số reviews đã duyệt: 1190000)...
# Đã xử lý chunk 119: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 112
# Tổng số người dùng hiện tại: 103
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 120 (tổng số reviews đã duyệt: 1200000)...
# Đã xử lý chunk 120: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 114
# Tổng số người dùng hiện tại: 105
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 121 (tổng số reviews đã duyệt: 1210000)...
# Đã xử lý chunk 121: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 115
# Tổng số người dùng hiện tại: 106
# Thời gian xử lý chunk: 0.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 122 (tổng số reviews đã duyệt: 1220000)...
# Đã xử lý chunk 122: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 116
# Tổng số người dùng hiện tại: 107
# Thời gian xử lý chunk: 0.75 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 123 (tổng số reviews đã duyệt: 1230000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 124 (tổng số reviews đã duyệt: 1240000)...
# Đã xử lý chunk 124: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 118
# Tổng số người dùng hiện tại: 109
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 125 (tổng số reviews đã duyệt: 1250000)...
# Đã xử lý chunk 125: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 119
# Tổng số người dùng hiện tại: 110
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 126 (tổng số reviews đã duyệt: 1260000)...
# Đã xử lý chunk 126: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 120
# Tổng số người dùng hiện tại: 111
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 127 (tổng số reviews đã duyệt: 1270000)...
# Đã xử lý chunk 127: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 121
# Tổng số người dùng hiện tại: 112
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 128 (tổng số reviews đã duyệt: 1280000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 129 (tổng số reviews đã duyệt: 1290000)...
# Đã xử lý chunk 129: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 122
# Tổng số người dùng hiện tại: 113
# Thời gian xử lý chunk: 0.50 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 130 (tổng số reviews đã duyệt: 1300000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 131 (tổng số reviews đã duyệt: 1310000)...
# Đã xử lý chunk 131: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 126
# Tổng số người dùng hiện tại: 117
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 132 (tổng số reviews đã duyệt: 1320000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 133 (tổng số reviews đã duyệt: 1330000)...
# Đã xử lý chunk 133: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 127
# Tổng số người dùng hiện tại: 118
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 134 (tổng số reviews đã duyệt: 1340000)...
# Đã xử lý chunk 134: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 129
# Tổng số người dùng hiện tại: 120
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 135 (tổng số reviews đã duyệt: 1350000)...
# Đã xử lý chunk 135: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 130
# Tổng số người dùng hiện tại: 121
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 136 (tổng số reviews đã duyệt: 1360000)...
# Đã xử lý chunk 136: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 133
# Tổng số người dùng hiện tại: 124
# Thời gian xử lý chunk: 0.99 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 137 (tổng số reviews đã duyệt: 1370000)...
# Đã xử lý chunk 137: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 134
# Tổng số người dùng hiện tại: 125
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 138 (tổng số reviews đã duyệt: 1380000)...
# Đã xử lý chunk 138: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 135
# Tổng số người dùng hiện tại: 126
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 139 (tổng số reviews đã duyệt: 1390000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 140 (tổng số reviews đã duyệt: 1400000)...
# Đã xử lý chunk 140: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 136
# Tổng số người dùng hiện tại: 127
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 141 (tổng số reviews đã duyệt: 1410000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 142 (tổng số reviews đã duyệt: 1420000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 143 (tổng số reviews đã duyệt: 1430000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 144 (tổng số reviews đã duyệt: 1440000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 145 (tổng số reviews đã duyệt: 1450000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 146 (tổng số reviews đã duyệt: 1460000)...
# Đã xử lý chunk 146: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 137
# Tổng số người dùng hiện tại: 128
# Thời gian xử lý chunk: 0.60 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 147 (tổng số reviews đã duyệt: 1470000)...
# Đã xử lý chunk 147: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 138
# Tổng số người dùng hiện tại: 129
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 148 (tổng số reviews đã duyệt: 1480000)...
# Đã xử lý chunk 148: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 139
# Tổng số người dùng hiện tại: 130
# Thời gian xử lý chunk: 1.04 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 149 (tổng số reviews đã duyệt: 1490000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 150 (tổng số reviews đã duyệt: 1500000)...
# Đã xử lý chunk 150: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 140
# Tổng số người dùng hiện tại: 131
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 151 (tổng số reviews đã duyệt: 1510000)...
# Đã xử lý chunk 151: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 144
# Tổng số người dùng hiện tại: 135
# Thời gian xử lý chunk: 0.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 152 (tổng số reviews đã duyệt: 1520000)...
# Đã xử lý chunk 152: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 145
# Tổng số người dùng hiện tại: 136
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 153 (tổng số reviews đã duyệt: 1530000)...
# Đã xử lý chunk 153: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 146
# Tổng số người dùng hiện tại: 137
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 154 (tổng số reviews đã duyệt: 1540000)...
# Đã xử lý chunk 154: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 147
# Tổng số người dùng hiện tại: 138
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 155 (tổng số reviews đã duyệt: 1550000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 156 (tổng số reviews đã duyệt: 1560000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 157 (tổng số reviews đã duyệt: 1570000)...
# Đã xử lý chunk 157: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 148
# Tổng số người dùng hiện tại: 139
# Thời gian xử lý chunk: 0.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 158 (tổng số reviews đã duyệt: 1580000)...
# Đã xử lý chunk 158: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 152
# Tổng số người dùng hiện tại: 143
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 159 (tổng số reviews đã duyệt: 1590000)...
# Đã xử lý chunk 159: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 153
# Tổng số người dùng hiện tại: 144
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 160 (tổng số reviews đã duyệt: 1600000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 161 (tổng số reviews đã duyệt: 1610000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 162 (tổng số reviews đã duyệt: 1620000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 163 (tổng số reviews đã duyệt: 1630000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 164 (tổng số reviews đã duyệt: 1640000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 165 (tổng số reviews đã duyệt: 1650000)...
# Đã xử lý chunk 165: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 154
# Tổng số người dùng hiện tại: 145
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 166 (tổng số reviews đã duyệt: 1660000)...
# Đã xử lý chunk 166: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 155
# Tổng số người dùng hiện tại: 146
# Thời gian xử lý chunk: 0.64 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 167 (tổng số reviews đã duyệt: 1670000)...
# Đã xử lý chunk 167: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 156
# Tổng số người dùng hiện tại: 147
# Thời gian xử lý chunk: 0.69 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 168 (tổng số reviews đã duyệt: 1680000)...
# Đã xử lý chunk 168: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 157
# Tổng số người dùng hiện tại: 148
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 169 (tổng số reviews đã duyệt: 1690000)...
# Đã xử lý chunk 169: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 158
# Tổng số người dùng hiện tại: 149
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 170 (tổng số reviews đã duyệt: 1700000)...
# Đã xử lý chunk 170: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 159
# Tổng số người dùng hiện tại: 150
# Thời gian xử lý chunk: 1.67 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 171 (tổng số reviews đã duyệt: 1710000)...
# Đã xử lý chunk 171: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 160
# Tổng số người dùng hiện tại: 151
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 172 (tổng số reviews đã duyệt: 1720000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 173 (tổng số reviews đã duyệt: 1730000)...
# Đã xử lý chunk 173: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 161
# Tổng số người dùng hiện tại: 152
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 174 (tổng số reviews đã duyệt: 1740000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 175 (tổng số reviews đã duyệt: 1750000)...
# Đã xử lý chunk 175: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 162
# Tổng số người dùng hiện tại: 153
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 176 (tổng số reviews đã duyệt: 1760000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 177 (tổng số reviews đã duyệt: 1770000)...
# Đã xử lý chunk 177: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 163
# Tổng số người dùng hiện tại: 154
# Thời gian xử lý chunk: 1.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 178 (tổng số reviews đã duyệt: 1780000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 179 (tổng số reviews đã duyệt: 1790000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 180 (tổng số reviews đã duyệt: 1800000)...
# Đã xử lý chunk 180: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 164
# Tổng số người dùng hiện tại: 155
# Thời gian xử lý chunk: 0.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 181 (tổng số reviews đã duyệt: 1810000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 182 (tổng số reviews đã duyệt: 1820000)...
# Đã xử lý chunk 182: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 165
# Tổng số người dùng hiện tại: 156
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 183 (tổng số reviews đã duyệt: 1830000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 184 (tổng số reviews đã duyệt: 1840000)...
# Đã xử lý chunk 184: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 167
# Tổng số người dùng hiện tại: 158
# Thời gian xử lý chunk: 0.58 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 185 (tổng số reviews đã duyệt: 1850000)...
# Đã xử lý chunk 185: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 168
# Tổng số người dùng hiện tại: 159
# Thời gian xử lý chunk: 0.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 186 (tổng số reviews đã duyệt: 1860000)...
# Đã xử lý chunk 186: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 170
# Tổng số người dùng hiện tại: 161
# Thời gian xử lý chunk: 1.25 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 187 (tổng số reviews đã duyệt: 1870000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 188 (tổng số reviews đã duyệt: 1880000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 189 (tổng số reviews đã duyệt: 1890000)...
# Đã xử lý chunk 189: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 172
# Tổng số người dùng hiện tại: 163
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 190 (tổng số reviews đã duyệt: 1900000)...
# Đã xử lý chunk 190: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 173
# Tổng số người dùng hiện tại: 164
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 191 (tổng số reviews đã duyệt: 1910000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 192 (tổng số reviews đã duyệt: 1920000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 193 (tổng số reviews đã duyệt: 1930000)...
# Đã xử lý chunk 193: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 175
# Tổng số người dùng hiện tại: 166
# Thời gian xử lý chunk: 1.04 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 194 (tổng số reviews đã duyệt: 1940000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 195 (tổng số reviews đã duyệt: 1950000)...
# Đã xử lý chunk 195: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 176
# Tổng số người dùng hiện tại: 167
# Thời gian xử lý chunk: 0.62 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 196 (tổng số reviews đã duyệt: 1960000)...
# Đã xử lý chunk 196: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 177
# Tổng số người dùng hiện tại: 168
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 197 (tổng số reviews đã duyệt: 1970000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 198 (tổng số reviews đã duyệt: 1980000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 199 (tổng số reviews đã duyệt: 1990000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 200 (tổng số reviews đã duyệt: 2000000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 201 (tổng số reviews đã duyệt: 2010000)...
# Đã xử lý chunk 201: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 179
# Tổng số người dùng hiện tại: 170
# Thời gian xử lý chunk: 1.28 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 202 (tổng số reviews đã duyệt: 2020000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 203 (tổng số reviews đã duyệt: 2030000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 204 (tổng số reviews đã duyệt: 2040000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 205 (tổng số reviews đã duyệt: 2050000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 206 (tổng số reviews đã duyệt: 2060000)...
# Đã xử lý chunk 206: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 180
# Tổng số người dùng hiện tại: 171
# Thời gian xử lý chunk: 0.60 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 207 (tổng số reviews đã duyệt: 2070000)...
# Đã xử lý chunk 207: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 181
# Tổng số người dùng hiện tại: 172
# Thời gian xử lý chunk: 0.65 giây
# ...
# Tổng số reviews đã xử lý: 232
# Tổng số người dùng hiện tại: 214
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 267 (tổng số reviews đã duyệt: 2670000)...
# Đã xử lý chunk 267: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 233
# Tổng số người dùng hiện tại: 215
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 268 (tổng số reviews đã duyệt: 2680000)...
# Đã xử lý chunk 268: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 234
# Tổng số người dùng hiện tại: 216
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 269 (tổng số reviews đã duyệt: 2690000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 270 (tổng số reviews đã duyệt: 2700000)...
# Đã xử lý chunk 270: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 236
# Tổng số người dùng hiện tại: 218
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 271 (tổng số reviews đã duyệt: 2710000)...
# Đã xử lý chunk 271: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 238
# Tổng số người dùng hiện tại: 220
# Thời gian xử lý chunk: 0.52 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 272 (tổng số reviews đã duyệt: 2720000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 273 (tổng số reviews đã duyệt: 2730000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 274 (tổng số reviews đã duyệt: 2740000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 275 (tổng số reviews đã duyệt: 2750000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 276 (tổng số reviews đã duyệt: 2760000)...
# Đã xử lý chunk 276: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 239
# Tổng số người dùng hiện tại: 221
# Thời gian xử lý chunk: 0.96 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 277 (tổng số reviews đã duyệt: 2770000)...
# Đã xử lý chunk 277: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 241
# Tổng số người dùng hiện tại: 223
# Thời gian xử lý chunk: 0.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 278 (tổng số reviews đã duyệt: 2780000)...
# Đã xử lý chunk 278: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 242
# Tổng số người dùng hiện tại: 224
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 279 (tổng số reviews đã duyệt: 2790000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 280 (tổng số reviews đã duyệt: 2800000)...
# Đã xử lý chunk 280: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 243
# Tổng số người dùng hiện tại: 225
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 281 (tổng số reviews đã duyệt: 2810000)...
# Đã xử lý chunk 281: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 244
# Tổng số người dùng hiện tại: 226
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 282 (tổng số reviews đã duyệt: 2820000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 283 (tổng số reviews đã duyệt: 2830000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 284 (tổng số reviews đã duyệt: 2840000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 285 (tổng số reviews đã duyệt: 2850000)...
# Đã xử lý chunk 285: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 246
# Tổng số người dùng hiện tại: 228
# Thời gian xử lý chunk: 0.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 286 (tổng số reviews đã duyệt: 2860000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 287 (tổng số reviews đã duyệt: 2870000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 288 (tổng số reviews đã duyệt: 2880000)...
# Đã xử lý chunk 288: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 247
# Tổng số người dùng hiện tại: 229
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 289 (tổng số reviews đã duyệt: 2890000)...
# Đã xử lý chunk 289: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 248
# Tổng số người dùng hiện tại: 230
# Thời gian xử lý chunk: 1.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 290 (tổng số reviews đã duyệt: 2900000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 291 (tổng số reviews đã duyệt: 2910000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 292 (tổng số reviews đã duyệt: 2920000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 293 (tổng số reviews đã duyệt: 2930000)...
# Đã xử lý chunk 293: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 249
# Tổng số người dùng hiện tại: 231
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 294 (tổng số reviews đã duyệt: 2940000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 295 (tổng số reviews đã duyệt: 2950000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 296 (tổng số reviews đã duyệt: 2960000)...
# Đã xử lý chunk 296: 2 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 251
# Tổng số người dùng hiện tại: 232
# Thời gian xử lý chunk: 3.24 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 297 (tổng số reviews đã duyệt: 2970000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 298 (tổng số reviews đã duyệt: 2980000)...
# Đã xử lý chunk 298: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 253
# Tổng số người dùng hiện tại: 234
# Thời gian xử lý chunk: 1.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 299 (tổng số reviews đã duyệt: 2990000)...
# Đã xử lý chunk 299: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 254
# Tổng số người dùng hiện tại: 235
# Thời gian xử lý chunk: 0.67 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 300 (tổng số reviews đã duyệt: 3000000)...
# Đã xử lý chunk 300: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 255
# Tổng số người dùng hiện tại: 236
# Thời gian xử lý chunk: 0.69 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 301 (tổng số reviews đã duyệt: 3010000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 302 (tổng số reviews đã duyệt: 3020000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 303 (tổng số reviews đã duyệt: 3030000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 304 (tổng số reviews đã duyệt: 3040000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 305 (tổng số reviews đã duyệt: 3050000)...
# Đã xử lý chunk 305: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 256
# Tổng số người dùng hiện tại: 237
# Thời gian xử lý chunk: 1.02 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 306 (tổng số reviews đã duyệt: 3060000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 307 (tổng số reviews đã duyệt: 3070000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 308 (tổng số reviews đã duyệt: 3080000)...
# Đã xử lý chunk 308: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 257
# Tổng số người dùng hiện tại: 238
# Thời gian xử lý chunk: 0.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 309 (tổng số reviews đã duyệt: 3090000)...
# Đã xử lý chunk 309: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 260
# Tổng số người dùng hiện tại: 241
# Thời gian xử lý chunk: 0.61 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 310 (tổng số reviews đã duyệt: 3100000)...
# Đã xử lý chunk 310: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 261
# Tổng số người dùng hiện tại: 242
# Thời gian xử lý chunk: 1.10 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 311 (tổng số reviews đã duyệt: 3110000)...
# Đã xử lý chunk 311: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 263
# Tổng số người dùng hiện tại: 244
# Thời gian xử lý chunk: 0.61 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 312 (tổng số reviews đã duyệt: 3120000)...
# Đã xử lý chunk 312: 4 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 267
# Tổng số người dùng hiện tại: 247
# Thời gian xử lý chunk: 0.61 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 313 (tổng số reviews đã duyệt: 3130000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 314 (tổng số reviews đã duyệt: 3140000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 315 (tổng số reviews đã duyệt: 3150000)...
# Đã xử lý chunk 315: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 268
# Tổng số người dùng hiện tại: 248
# Thời gian xử lý chunk: 0.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 316 (tổng số reviews đã duyệt: 3160000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 317 (tổng số reviews đã duyệt: 3170000)...
# Đã xử lý chunk 317: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 269
# Tổng số người dùng hiện tại: 249
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 318 (tổng số reviews đã duyệt: 3180000)...
# Đã xử lý chunk 318: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 270
# Tổng số người dùng hiện tại: 250
# Thời gian xử lý chunk: 0.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 319 (tổng số reviews đã duyệt: 3190000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 320 (tổng số reviews đã duyệt: 3200000)...
# Đã xử lý chunk 320: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 271
# Tổng số người dùng hiện tại: 251
# Thời gian xử lý chunk: 0.67 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 321 (tổng số reviews đã duyệt: 3210000)...
# Đã xử lý chunk 321: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 272
# Tổng số người dùng hiện tại: 252
# Thời gian xử lý chunk: 0.58 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 322 (tổng số reviews đã duyệt: 3220000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 323 (tổng số reviews đã duyệt: 3230000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 324 (tổng số reviews đã duyệt: 3240000)...
# Đã xử lý chunk 324: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 274
# Tổng số người dùng hiện tại: 254
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 325 (tổng số reviews đã duyệt: 3250000)...
# Đã xử lý chunk 325: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 275
# Tổng số người dùng hiện tại: 255
# Thời gian xử lý chunk: 0.67 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 326 (tổng số reviews đã duyệt: 3260000)...
# Đã xử lý chunk 326: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 276
# Tổng số người dùng hiện tại: 256
# Thời gian xử lý chunk: 0.62 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 327 (tổng số reviews đã duyệt: 3270000)...
# Đã xử lý chunk 327: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 277
# Tổng số người dùng hiện tại: 257
# Thời gian xử lý chunk: 0.73 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 328 (tổng số reviews đã duyệt: 3280000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 329 (tổng số reviews đã duyệt: 3290000)...
# Đã xử lý chunk 329: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 278
# Tổng số người dùng hiện tại: 258
# Thời gian xử lý chunk: 0.87 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 330 (tổng số reviews đã duyệt: 3300000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 331 (tổng số reviews đã duyệt: 3310000)...
# Đã xử lý chunk 331: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 279
# Tổng số người dùng hiện tại: 259
# Thời gian xử lý chunk: 1.17 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 332 (tổng số reviews đã duyệt: 3320000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 333 (tổng số reviews đã duyệt: 3330000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 334 (tổng số reviews đã duyệt: 3340000)...
# Đã xử lý chunk 334: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 280
# Tổng số người dùng hiện tại: 260
# Thời gian xử lý chunk: 1.24 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
#
# Bắt đầu xử lý chunk 335 (tổng số reviews đã duyệt: 3350000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 336 (tổng số reviews đã duyệt: 3360000)...
# Đã xử lý chunk 336: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 281
# Tổng số người dùng hiện tại: 261
# Thời gian xử lý chunk: 0.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
# Chờ 10 giây trước khi xử lý chunk tiếp theo...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 189
#     187     # Thêm thời gian chờ để tránh lỗi 429
#     188     print("Chờ 10 giây trước khi xử lý chunk tiếp theo...")
# --> 189     time.sleep(10)
#     191 # Xử lý chunk cuối (nếu có)
#     192 if chunk_reviews:
#
# KeyboardInterrupt:

# %%
# Script chạy trên máy local để xử lý dataset Amazon-Reviews-2023 (raw_review_Books) với streaming

# Bước 1: Import các thư viện
import pandas as pd
from datasets import load_dataset
from datetime import datetime
import json
import os
import time

# Bước 2: Thiết lập HF_TOKEN
# Cách 1: Đặt HF_TOKEN trực tiếp trong code (không khuyến nghị vì lý do bảo mật)
# HF_TOKEN = "hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"  # Thay bằng token của bạn

# Cách 2: Đặt HF_TOKEN qua biến môi trường (khuyến nghị)
# Trên Windows: set HF_TOKEN=hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Trên macOS/Linux: export HF_TOKEN=hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
HF_TOKEN = "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"
if not HF_TOKEN:
    raise ValueError("HF_TOKEN không được tìm thấy. Vui lòng đặt HF_TOKEN trong biến môi trường hoặc trong code.")

# Đường dẫn file (thay đổi theo máy local của bạn)
EXACT_MATCHED_BOOKS_PATH = r"C:\Users\thait\LABS\NC\cit-meta\exact_matched_books.csv"
AMAZON_USER_PATH = r"C:\Users\thait\LABS\NC\cit-meta\AmazonUser.csv"
AMAZON_RATING_PATH = r"C:\Users\thait\LABS\NC\cit-meta\AmazonRating.csv"
PRETRAIN_DATA_PATH = r"C:\Users\thait\LABS\NC\cit-meta\PretrainData.csv"
CHECKPOINT_PATH = r"C:\Users\thait\LABS\NC\cit-meta\checkpoint.json"

# Tạo thư mục nếu chưa tồn tại
os.makedirs(os.path.dirname(EXACT_MATCHED_BOOKS_PATH), exist_ok=True)

# Bước 3: Đọc exact_matched_books.csv và tạo tập hợp parent_asin
print("Đang đọc file exact_matched_books.csv...")
exact_matched_books = pd.read_csv(EXACT_MATCHED_BOOKS_PATH)
asin_to_book_id = dict(zip(exact_matched_books['parent_asin'], exact_matched_books['book_id']))
parent_asins = set(asin_to_book_id.keys())
print(f"Đã đọc {len(parent_asins)} parent_asin")

# Bước 4: Tải dataset với streaming
start_time = time.time()
print("Đang tải dataset Amazon-Reviews-2023 (raw_review_Books) với streaming...")
dataset = load_dataset(
    "McAuley-Lab/Amazon-Reviews-2023",
    "raw_review_Books",
    trust_remote_code=True,
    streaming=True,
    token=HF_TOKEN  # Sử dụng HF_TOKEN để tăng giới hạn rate limit
)

# Bước 5: Khởi tạo checkpoint
checkpoint = {
    'processed_reviews': 0,
    'user_mapping': {},
    'next_user_id': 1,
    'last_chunk_processed': 0
}
try:
    with open(CHECKPOINT_PATH, 'r') as f:
        checkpoint = json.load(f)
    print(f"Đã khôi phục checkpoint: {checkpoint['processed_reviews']} reviews đã được xử lý trước đó")
except FileNotFoundError:
    print("Không tìm thấy checkpoint, bắt đầu từ đầu")

user_mapping = checkpoint['user_mapping']
next_user_id = checkpoint['next_user_id']
processed_reviews = checkpoint['processed_reviews']
last_chunk_processed = checkpoint['last_chunk_processed']

# Tạo file CSV nếu chưa tồn tại hoặc append mode
def initialize_csv_files():
    if last_chunk_processed == 0:
        pd.DataFrame(columns=['id', 'amazon_user_id']).to_csv(AMAZON_USER_PATH, index=False)
        pd.DataFrame(columns=['amazon_user_id', 'book_id', 'rating', 'timestamp']).to_csv(AMAZON_RATING_PATH, index=False)
        pd.DataFrame(columns=['user_id', 'book_id', 'rating']).to_csv(PRETRAIN_DATA_PATH, index=False)

initialize_csv_files()

# Bước 6: Xử lý dữ liệu theo chunks với streaming
CHUNK_SIZE = 20000
chunk_reviews = []
iterator = iter(dataset['full'])
chunk_count = 0
total_reviews_processed = 0

# Bỏ qua các chunk đã xử lý
for _ in range(last_chunk_processed * CHUNK_SIZE):
    try:
        next(iterator)
        total_reviews_processed += 1
    except StopIteration:
        break

while True:
    start_chunk_time = time.time()
    chunk_reviews = []
    try:
        for _ in range(CHUNK_SIZE):
            review = next(iterator)
            if review['parent_asin'] in parent_asins:
                chunk_reviews.append(review)
            total_reviews_processed += 1
    except StopIteration:
        if not chunk_reviews:
            break

    chunk_count += 1
    print(f"\nBắt đầu xử lý chunk {chunk_count} (tổng số reviews đã duyệt: {total_reviews_processed})...")

    if not chunk_reviews:
        print("Chunk rỗng, tiếp tục...")
        continue

    # Chuyển chunk thành DataFrame để xử lý nhanh hơn
    chunk_df = pd.DataFrame(chunk_reviews)
    chunk_df['book_id'] = chunk_df['parent_asin'].map(asin_to_book_id)
    chunk_df['rating'] = chunk_df['rating'].astype(float)
    chunk_df['timestamp'] = chunk_df['timestamp'].apply(lambda x: datetime.fromtimestamp(x / 1000.0).strftime('%Y-%m-%d %H:%M:%S.%f'))

    # Lọc các rating không hợp lệ
    invalid_ratings = chunk_df[~chunk_df['rating'].between(1, 5)]
    for _, row in invalid_ratings.iterrows():
        print(f"Cảnh báo: Rating không hợp lệ ({row['rating']}) cho user {row['user_id']}, book_id {row['book_id']}, bỏ qua...")
    chunk_df = chunk_df[chunk_df['rating'].between(1, 5)]

    # Xử lý người dùng mới
    new_users = chunk_df[~chunk_df['user_id'].isin(user_mapping.keys())]['user_id'].unique()
    new_users_df = pd.DataFrame({
        'id': range(next_user_id, next_user_id + len(new_users)),
        'amazon_user_id': new_users
    })
    if not new_users_df.empty:
        new_user_mapping = dict(zip(new_users, new_users_df['id']))
        user_mapping.update(new_user_mapping)
        next_user_id += len(new_users)
        # Append vào file CSV
        new_users_df.to_csv(AMAZON_USER_PATH, mode='a', header=False, index=False)

    # Tạo dữ liệu amazon_ratings và pretrain_data
    chunk_df['user_id_mapped'] = chunk_df['user_id'].map(user_mapping)
    amazon_ratings_df = chunk_df[['user_id', 'book_id', 'rating', 'timestamp']].copy()
    amazon_ratings_df.rename(columns={'user_id': 'amazon_user_id'}, inplace=True)
    pretrain_data_df = pd.DataFrame({
        'user_id': chunk_df['user_id_mapped'].apply(lambda x: f"AMZ_{x}"),
        'book_id': chunk_df['book_id'],
        'rating': chunk_df['rating']
    })

    # Append vào file CSV
    amazon_ratings_df.to_csv(AMAZON_RATING_PATH, mode='a', header=False, index=False)
    pretrain_data_df.to_csv(PRETRAIN_DATA_PATH, mode='a', header=False, index=False)

    processed_reviews += len(chunk_df)
    print(f"Đã xử lý chunk {chunk_count}: {len(chunk_df)} đánh giá hợp lệ, {len(new_users)} người dùng mới được thêm")
    print(f"Tổng số reviews đã xử lý: {processed_reviews}")
    print(f"Tổng số người dùng hiện tại: {len(user_mapping)}")
    print(f"Thời gian xử lý chunk: {time.time() - start_chunk_time:.2f} giây")

    # Cập nhật checkpoint
    checkpoint['processed_reviews'] = processed_reviews
    checkpoint['user_mapping'] = user_mapping
    checkpoint['next_user_id'] = next_user_id
    checkpoint['last_chunk_processed'] = chunk_count
    with open(CHECKPOINT_PATH, 'w') as f:
        json.dump(checkpoint, f)
    print(f"Đã lưu checkpoint tại {CHECKPOINT_PATH}")

# Xử lý chunk cuối (nếu có)
if chunk_reviews:
    start_chunk_time = time.time()
    chunk_count += 1
    print(f"\nBắt đầu xử lý chunk cuối {chunk_count} (tổng số reviews đã duyệt: {total_reviews_processed})...")

    chunk_df = pd.DataFrame(chunk_reviews)
    chunk_df['book_id'] = chunk_df['parent_asin'].map(asin_to_book_id)
    chunk_df['rating'] = chunk_df['rating'].astype(float)
    chunk_df['timestamp'] = chunk_df['timestamp'].apply(lambda x: datetime.fromtimestamp(x / 1000.0).strftime('%Y-%m-%d %H:%M:%S.%f'))

    invalid_ratings = chunk_df[~chunk_df['rating'].between(1, 5)]
    for _, row in invalid_ratings.iterrows():
        print(f"Cảnh báo: Rating không hợp lệ ({row['rating']}) cho user {row['user_id']}, book_id {row['book_id']}, bỏ qua...")
    chunk_df = chunk_df[chunk_df['rating'].between(1, 5)]

    new_users = chunk_df[~chunk_df['user_id'].isin(user_mapping.keys())]['user_id'].unique()
    new_users_df = pd.DataFrame({
        'id': range(next_user_id, next_user_id + len(new_users)),
        'amazon_user_id': new_users
    })
    if not new_users_df.empty:
        new_user_mapping = dict(zip(new_users, new_users_df['id']))
        user_mapping.update(new_user_mapping)
        next_user_id += len(new_users)
        new_users_df.to_csv(AMAZON_USER_PATH, mode='a', header=False, index=False)

    chunk_df['user_id_mapped'] = chunk_df['user_id'].map(user_mapping)
    amazon_ratings_df = chunk_df[['user_id', 'book_id', 'rating', 'timestamp']].copy()
    amazon_ratings_df.rename(columns={'user_id': 'amazon_user_id'}, inplace=True)
    pretrain_data_df = pd.DataFrame({
        'user_id': chunk_df['user_id_mapped'].apply(lambda x: f"AMZ_{x}"),
        'book_id': chunk_df['book_id'],
        'rating': chunk_df['rating']
    })

    amazon_ratings_df.to_csv(AMAZON_RATING_PATH, mode='a', header=False, index=False)
    pretrain_data_df.to_csv(PRETRAIN_DATA_PATH, mode='a', header=False, index=False)

    processed_reviews += len(chunk_df)
    print(f"Đã xử lý chunk cuối: {len(chunk_df)} đánh giá hợp lệ, {len(new_users)} người dùng mới được thêm")
    print(f"Tổng số reviews đã xử lý: {processed_reviews}")
    print(f"Tổng số người dùng hiện tại: {len(user_mapping)}")
    print(f"Thời gian xử lý chunk cuối: {time.time() - start_chunk_time:.2f} giây")

    checkpoint['processed_reviews'] = processed_reviews
    checkpoint['user_mapping'] = user_mapping
    checkpoint['next_user_id'] = next_user_id
    checkpoint['last_chunk_processed'] = chunk_count
    with open(CHECKPOINT_PATH, 'w') as f:
        json.dump(checkpoint, f)
    print(f"Đã lưu checkpoint cuối tại {CHECKPOINT_PATH}")

print(f"\nHoàn tất quá trình xử lý! Tổng thời gian: {(time.time() - start_time) / 60:.2f} phút")
# Out:
# Đang đọc file exact_matched_books.csv...
# Đã đọc 204 parent_asin
# Đang tải dataset Amazon-Reviews-2023 (raw_review_Books) với streaming...
# Không tìm thấy checkpoint, bắt đầu từ đầu
#
# Bắt đầu xử lý chunk 1 (tổng số reviews đã duyệt: 20000)...
# Đã xử lý chunk 1: 6 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 6
# Tổng số người dùng hiện tại: 2
# Thời gian xử lý chunk: 3.37 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 2 (tổng số reviews đã duyệt: 40000)...
# Đã xử lý chunk 2: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 7
# Tổng số người dùng hiện tại: 3
# Thời gian xử lý chunk: 2.60 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 3 (tổng số reviews đã duyệt: 60000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 4 (tổng số reviews đã duyệt: 80000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 5 (tổng số reviews đã duyệt: 100000)...
# Đã xử lý chunk 5: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 9
# Tổng số người dùng hiện tại: 5
# Thời gian xử lý chunk: 1.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 6 (tổng số reviews đã duyệt: 120000)...
# Đã xử lý chunk 6: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 12
# Tổng số người dùng hiện tại: 8
# Thời gian xử lý chunk: 1.81 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 7 (tổng số reviews đã duyệt: 140000)...
# Đã xử lý chunk 7: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 14
# Tổng số người dùng hiện tại: 10
# Thời gian xử lý chunk: 2.20 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 8 (tổng số reviews đã duyệt: 160000)...
# Đã xử lý chunk 8: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 17
# Tổng số người dùng hiện tại: 13
# Thời gian xử lý chunk: 1.66 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 9 (tổng số reviews đã duyệt: 180000)...
# Đã xử lý chunk 9: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 18
# Tổng số người dùng hiện tại: 14
# Thời gian xử lý chunk: 1.06 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 10 (tổng số reviews đã duyệt: 200000)...
# Đã xử lý chunk 10: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 19
# Tổng số người dùng hiện tại: 15
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 11 (tổng số reviews đã duyệt: 220000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 12 (tổng số reviews đã duyệt: 240000)...
# Đã xử lý chunk 12: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 21
# Tổng số người dùng hiện tại: 17
# Thời gian xử lý chunk: 1.23 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 13 (tổng số reviews đã duyệt: 260000)...
# Đã xử lý chunk 13: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 22
# Tổng số người dùng hiện tại: 18
# Thời gian xử lý chunk: 3.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 14 (tổng số reviews đã duyệt: 280000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 15 (tổng số reviews đã duyệt: 300000)...
# Đã xử lý chunk 15: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 25
# Tổng số người dùng hiện tại: 21
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 16 (tổng số reviews đã duyệt: 320000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 17 (tổng số reviews đã duyệt: 340000)...
# Đã xử lý chunk 17: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 28
# Tổng số người dùng hiện tại: 24
# Thời gian xử lý chunk: 1.95 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 18 (tổng số reviews đã duyệt: 360000)...
# Đã xử lý chunk 18: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 30
# Tổng số người dùng hiện tại: 26
# Thời gian xử lý chunk: 1.25 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 19 (tổng số reviews đã duyệt: 380000)...
# Đã xử lý chunk 19: 3 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 33
# Tổng số người dùng hiện tại: 27
# Thời gian xử lý chunk: 1.09 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 20 (tổng số reviews đã duyệt: 400000)...
# Đã xử lý chunk 20: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 36
# Tổng số người dùng hiện tại: 30
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 21 (tổng số reviews đã duyệt: 420000)...
# Đã xử lý chunk 21: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 37
# Tổng số người dùng hiện tại: 31
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 22 (tổng số reviews đã duyệt: 440000)...
# Đã xử lý chunk 22: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 41
# Tổng số người dùng hiện tại: 35
# Thời gian xử lý chunk: 1.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 23 (tổng số reviews đã duyệt: 460000)...
# Đã xử lý chunk 23: 7 đánh giá hợp lệ, 7 người dùng mới được thêm
# Tổng số reviews đã xử lý: 48
# Tổng số người dùng hiện tại: 42
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 24 (tổng số reviews đã duyệt: 480000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 25 (tổng số reviews đã duyệt: 500000)...
# Đã xử lý chunk 25: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 49
# Tổng số người dùng hiện tại: 43
# Thời gian xử lý chunk: 1.28 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 26 (tổng số reviews đã duyệt: 520000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 27 (tổng số reviews đã duyệt: 540000)...
# Đã xử lý chunk 27: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 52
# Tổng số người dùng hiện tại: 46
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 28 (tổng số reviews đã duyệt: 560000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 29 (tổng số reviews đã duyệt: 580000)...
# Đã xử lý chunk 29: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 55
# Tổng số người dùng hiện tại: 49
# Thời gian xử lý chunk: 3.96 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 30 (tổng số reviews đã duyệt: 600000)...
# Đã xử lý chunk 30: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 59
# Tổng số người dùng hiện tại: 53
# Thời gian xử lý chunk: 1.65 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 31 (tổng số reviews đã duyệt: 620000)...
# Đã xử lý chunk 31: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 60
# Tổng số người dùng hiện tại: 54
# Thời gian xử lý chunk: 1.04 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 32 (tổng số reviews đã duyệt: 640000)...
# Đã xử lý chunk 32: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 62
# Tổng số người dùng hiện tại: 56
# Thời gian xử lý chunk: 1.15 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 33 (tổng số reviews đã duyệt: 660000)...
# Đã xử lý chunk 33: 5 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 67
# Tổng số người dùng hiện tại: 60
# Thời gian xử lý chunk: 1.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 34 (tổng số reviews đã duyệt: 680000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 35 (tổng số reviews đã duyệt: 700000)...
# Đã xử lý chunk 35: 5 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 72
# Tổng số người dùng hiện tại: 64
# Thời gian xử lý chunk: 2.29 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 36 (tổng số reviews đã duyệt: 720000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 37 (tổng số reviews đã duyệt: 740000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 38 (tổng số reviews đã duyệt: 760000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 39 (tổng số reviews đã duyệt: 780000)...
# Đã xử lý chunk 39: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 73
# Tổng số người dùng hiện tại: 65
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 40 (tổng số reviews đã duyệt: 800000)...
# Đã xử lý chunk 40: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 77
# Tổng số người dùng hiện tại: 69
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 41 (tổng số reviews đã duyệt: 820000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 42 (tổng số reviews đã duyệt: 840000)...
# Đã xử lý chunk 42: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 80
# Tổng số người dùng hiện tại: 72
# Thời gian xử lý chunk: 1.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 43 (tổng số reviews đã duyệt: 860000)...
# Đã xử lý chunk 43: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 81
# Tổng số người dùng hiện tại: 73
# Thời gian xử lý chunk: 1.72 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 44 (tổng số reviews đã duyệt: 880000)...
# Đã xử lý chunk 44: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 83
# Tổng số người dùng hiện tại: 75
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 45 (tổng số reviews đã duyệt: 900000)...
# Đã xử lý chunk 45: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 85
# Tổng số người dùng hiện tại: 77
# Thời gian xử lý chunk: 1.27 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 46 (tổng số reviews đã duyệt: 920000)...
# Đã xử lý chunk 46: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 89
# Tổng số người dùng hiện tại: 81
# Thời gian xử lý chunk: 1.92 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 47 (tổng số reviews đã duyệt: 940000)...
# Đã xử lý chunk 47: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 91
# Tổng số người dùng hiện tại: 83
# Thời gian xử lý chunk: 1.27 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 48 (tổng số reviews đã duyệt: 960000)...
# Đã xử lý chunk 48: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 92
# Tổng số người dùng hiện tại: 84
# Thời gian xử lý chunk: 1.31 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 49 (tổng số reviews đã duyệt: 980000)...
# Đã xử lý chunk 49: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 93
# Tổng số người dùng hiện tại: 85
# Thời gian xử lý chunk: 1.69 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 50 (tổng số reviews đã duyệt: 1000000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 51 (tổng số reviews đã duyệt: 1020000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 52 (tổng số reviews đã duyệt: 1040000)...
# Đã xử lý chunk 52: 4 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 97
# Tổng số người dùng hiện tại: 88
# Thời gian xử lý chunk: 1.29 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 53 (tổng số reviews đã duyệt: 1060000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 54 (tổng số reviews đã duyệt: 1080000)...
# Đã xử lý chunk 54: 5 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 102
# Tổng số người dùng hiện tại: 93
# Thời gian xử lý chunk: 1.72 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 55 (tổng số reviews đã duyệt: 1100000)...
# Đã xử lý chunk 55: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 103
# Tổng số người dùng hiện tại: 94
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 56 (tổng số reviews đã duyệt: 1120000)...
# Đã xử lý chunk 56: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 107
# Tổng số người dùng hiện tại: 98
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 57 (tổng số reviews đã duyệt: 1140000)...
# Đã xử lý chunk 57: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 108
# Tổng số người dùng hiện tại: 99
# Thời gian xử lý chunk: 1.20 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 58 (tổng số reviews đã duyệt: 1160000)...
# Đã xử lý chunk 58: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 109
# Tổng số người dùng hiện tại: 100
# Thời gian xử lý chunk: 1.15 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 59 (tổng số reviews đã duyệt: 1180000)...
# Đã xử lý chunk 59: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 111
# Tổng số người dùng hiện tại: 102
# Thời gian xử lý chunk: 1.76 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 60 (tổng số reviews đã duyệt: 1200000)...
# Đã xử lý chunk 60: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 114
# Tổng số người dùng hiện tại: 105
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 61 (tổng số reviews đã duyệt: 1220000)...
# Đã xử lý chunk 61: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 116
# Tổng số người dùng hiện tại: 107
# Thời gian xử lý chunk: 1.18 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 62 (tổng số reviews đã duyệt: 1240000)...
# Đã xử lý chunk 62: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 118
# Tổng số người dùng hiện tại: 109
# Thời gian xử lý chunk: 1.15 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 63 (tổng số reviews đã duyệt: 1260000)...
# Đã xử lý chunk 63: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 120
# Tổng số người dùng hiện tại: 111
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 64 (tổng số reviews đã duyệt: 1280000)...
# Đã xử lý chunk 64: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 121
# Tổng số người dùng hiện tại: 112
# Thời gian xử lý chunk: 1.26 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 65 (tổng số reviews đã duyệt: 1300000)...
# Đã xử lý chunk 65: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 122
# Tổng số người dùng hiện tại: 113
# Thời gian xử lý chunk: 1.73 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 66 (tổng số reviews đã duyệt: 1320000)...
# Đã xử lý chunk 66: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 126
# Tổng số người dùng hiện tại: 117
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 67 (tổng số reviews đã duyệt: 1340000)...
# Đã xử lý chunk 67: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 129
# Tổng số người dùng hiện tại: 120
# Thời gian xử lý chunk: 1.28 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 68 (tổng số reviews đã duyệt: 1360000)...
# Đã xử lý chunk 68: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 133
# Tổng số người dùng hiện tại: 124
# Thời gian xử lý chunk: 1.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 69 (tổng số reviews đã duyệt: 1380000)...
# Đã xử lý chunk 69: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 135
# Tổng số người dùng hiện tại: 126
# Thời gian xử lý chunk: 1.10 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 70 (tổng số reviews đã duyệt: 1400000)...
# Đã xử lý chunk 70: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 136
# Tổng số người dùng hiện tại: 127
# Thời gian xử lý chunk: 1.20 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 71 (tổng số reviews đã duyệt: 1420000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 72 (tổng số reviews đã duyệt: 1440000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 73 (tổng số reviews đã duyệt: 1460000)...
# Đã xử lý chunk 73: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 137
# Tổng số người dùng hiện tại: 128
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 74 (tổng số reviews đã duyệt: 1480000)...
# Đã xử lý chunk 74: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 139
# Tổng số người dùng hiện tại: 130
# Thời gian xử lý chunk: 1.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 75 (tổng số reviews đã duyệt: 1500000)...
# Đã xử lý chunk 75: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 140
# Tổng số người dùng hiện tại: 131
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 76 (tổng số reviews đã duyệt: 1520000)...
# Đã xử lý chunk 76: 5 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 145
# Tổng số người dùng hiện tại: 136
# Thời gian xử lý chunk: 1.28 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 77 (tổng số reviews đã duyệt: 1540000)...
# Đã xử lý chunk 77: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 147
# Tổng số người dùng hiện tại: 138
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 78 (tổng số reviews đã duyệt: 1560000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 79 (tổng số reviews đã duyệt: 1580000)...
# Đã xử lý chunk 79: 5 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 152
# Tổng số người dùng hiện tại: 143
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 80 (tổng số reviews đã duyệt: 1600000)...
# Đã xử lý chunk 80: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 153
# Tổng số người dùng hiện tại: 144
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 81 (tổng số reviews đã duyệt: 1620000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 82 (tổng số reviews đã duyệt: 1640000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 83 (tổng số reviews đã duyệt: 1660000)...
# Đã xử lý chunk 83: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 155
# Tổng số người dùng hiện tại: 146
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 84 (tổng số reviews đã duyệt: 1680000)...
# Đã xử lý chunk 84: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 157
# Tổng số người dùng hiện tại: 148
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 85 (tổng số reviews đã duyệt: 1700000)...
# Đã xử lý chunk 85: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 159
# Tổng số người dùng hiện tại: 150
# Thời gian xử lý chunk: 1.53 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 86 (tổng số reviews đã duyệt: 1720000)...
# Đã xử lý chunk 86: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 160
# Tổng số người dùng hiện tại: 151
# Thời gian xử lý chunk: 1.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 87 (tổng số reviews đã duyệt: 1740000)...
# Đã xử lý chunk 87: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 161
# Tổng số người dùng hiện tại: 152
# Thời gian xử lý chunk: 1.51 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 88 (tổng số reviews đã duyệt: 1760000)...
# Đã xử lý chunk 88: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 162
# Tổng số người dùng hiện tại: 153
# Thời gian xử lý chunk: 2.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 89 (tổng số reviews đã duyệt: 1780000)...
# Đã xử lý chunk 89: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 163
# Tổng số người dùng hiện tại: 154
# Thời gian xử lý chunk: 1.65 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 90 (tổng số reviews đã duyệt: 1800000)...
# Đã xử lý chunk 90: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 164
# Tổng số người dùng hiện tại: 155
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 91 (tổng số reviews đã duyệt: 1820000)...
# Đã xử lý chunk 91: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 165
# Tổng số người dùng hiện tại: 156
# Thời gian xử lý chunk: 1.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 92 (tổng số reviews đã duyệt: 1840000)...
# Đã xử lý chunk 92: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 167
# Tổng số người dùng hiện tại: 158
# Thời gian xử lý chunk: 1.09 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 93 (tổng số reviews đã duyệt: 1860000)...
# Đã xử lý chunk 93: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 170
# Tổng số người dùng hiện tại: 161
# Thời gian xử lý chunk: 1.64 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 94 (tổng số reviews đã duyệt: 1880000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 95 (tổng số reviews đã duyệt: 1900000)...
# Đã xử lý chunk 95: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 173
# Tổng số người dùng hiện tại: 164
# Thời gian xử lý chunk: 1.20 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 96 (tổng số reviews đã duyệt: 1920000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 97 (tổng số reviews đã duyệt: 1940000)...
# Đã xử lý chunk 97: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 175
# Tổng số người dùng hiện tại: 166
# Thời gian xử lý chunk: 1.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 98 (tổng số reviews đã duyệt: 1960000)...
# Đã xử lý chunk 98: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 177
# Tổng số người dùng hiện tại: 168
# Thời gian xử lý chunk: 1.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 99 (tổng số reviews đã duyệt: 1980000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 100 (tổng số reviews đã duyệt: 2000000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 101 (tổng số reviews đã duyệt: 2020000)...
# Đã xử lý chunk 101: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 179
# Tổng số người dùng hiện tại: 170
# Thời gian xử lý chunk: 1.69 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 102 (tổng số reviews đã duyệt: 2040000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 103 (tổng số reviews đã duyệt: 2060000)...
# Đã xử lý chunk 103: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 180
# Tổng số người dùng hiện tại: 171
# Thời gian xử lý chunk: 1.12 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 104 (tổng số reviews đã duyệt: 2080000)...
# Đã xử lý chunk 104: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 182
# Tổng số người dùng hiện tại: 173
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 105 (tổng số reviews đã duyệt: 2100000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 106 (tổng số reviews đã duyệt: 2120000)...
# Đã xử lý chunk 106: 6 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 188
# Tổng số người dùng hiện tại: 178
# Thời gian xử lý chunk: 2.27 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 107 (tổng số reviews đã duyệt: 2140000)...
# Đã xử lý chunk 107: 2 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 190
# Tổng số người dùng hiện tại: 179
# Thời gian xử lý chunk: 2.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 108 (tổng số reviews đã duyệt: 2160000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 109 (tổng số reviews đã duyệt: 2180000)...
# Đã xử lý chunk 109: 12 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 202
# Tổng số người dùng hiện tại: 184
# Thời gian xử lý chunk: 1.69 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 110 (tổng số reviews đã duyệt: 2200000)...
# Đã xử lý chunk 110: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 203
# Tổng số người dùng hiện tại: 185
# Thời gian xử lý chunk: 1.77 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 111 (tổng số reviews đã duyệt: 2220000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 112 (tổng số reviews đã duyệt: 2240000)...
# Đã xử lý chunk 112: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 205
# Tổng số người dùng hiện tại: 187
# Thời gian xử lý chunk: 2.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 113 (tổng số reviews đã duyệt: 2260000)...
# Đã xử lý chunk 113: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 208
# Tổng số người dùng hiện tại: 190
# Thời gian xử lý chunk: 1.67 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 114 (tổng số reviews đã duyệt: 2280000)...
# Đã xử lý chunk 114: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 210
# Tổng số người dùng hiện tại: 192
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 115 (tổng số reviews đã duyệt: 2300000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 116 (tổng số reviews đã duyệt: 2320000)...
# Đã xử lý chunk 116: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 211
# Tổng số người dùng hiện tại: 193
# Thời gian xử lý chunk: 1.09 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 117 (tổng số reviews đã duyệt: 2340000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 118 (tổng số reviews đã duyệt: 2360000)...
# Đã xử lý chunk 118: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 213
# Tổng số người dùng hiện tại: 195
# Thời gian xử lý chunk: 1.09 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 119 (tổng số reviews đã duyệt: 2380000)...
# Đã xử lý chunk 119: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 214
# Tổng số người dùng hiện tại: 196
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 120 (tổng số reviews đã duyệt: 2400000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 121 (tổng số reviews đã duyệt: 2420000)...
# Đã xử lý chunk 121: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 215
# Tổng số người dùng hiện tại: 197
# Thời gian xử lý chunk: 1.76 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 122 (tổng số reviews đã duyệt: 2440000)...
# Đã xử lý chunk 122: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 217
# Tổng số người dùng hiện tại: 199
# Thời gian xử lý chunk: 1.58 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 123 (tổng số reviews đã duyệt: 2460000)...
# Đã xử lý chunk 123: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 218
# Tổng số người dùng hiện tại: 200
# Thời gian xử lý chunk: 2.15 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 124 (tổng số reviews đã duyệt: 2480000)...
# Đã xử lý chunk 124: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 220
# Tổng số người dùng hiện tại: 202
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 125 (tổng số reviews đã duyệt: 2500000)...
# Đã xử lý chunk 125: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 221
# Tổng số người dùng hiện tại: 203
# Thời gian xử lý chunk: 1.71 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 126 (tổng số reviews đã duyệt: 2520000)...
# Đã xử lý chunk 126: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 222
# Tổng số người dùng hiện tại: 204
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 127 (tổng số reviews đã duyệt: 2540000)...
# Đã xử lý chunk 127: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 226
# Tổng số người dùng hiện tại: 208
# Thời gian xử lý chunk: 2.30 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 128 (tổng số reviews đã duyệt: 2560000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 129 (tổng số reviews đã duyệt: 2580000)...
# Đã xử lý chunk 129: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 227
# Tổng số người dùng hiện tại: 209
# Thời gian xử lý chunk: 1.61 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 130 (tổng số reviews đã duyệt: 2600000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 131 (tổng số reviews đã duyệt: 2620000)...
# Đã xử lý chunk 131: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 230
# Tổng số người dùng hiện tại: 212
# Thời gian xử lý chunk: 2.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 132 (tổng số reviews đã duyệt: 2640000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 133 (tổng số reviews đã duyệt: 2660000)...
# Đã xử lý chunk 133: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 232
# Tổng số người dùng hiện tại: 214
# Thời gian xử lý chunk: 1.88 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 134 (tổng số reviews đã duyệt: 2680000)...
# Đã xử lý chunk 134: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 234
# Tổng số người dùng hiện tại: 216
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 135 (tổng số reviews đã duyệt: 2700000)...
# Đã xử lý chunk 135: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 236
# Tổng số người dùng hiện tại: 218
# Thời gian xử lý chunk: 1.61 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 136 (tổng số reviews đã duyệt: 2720000)...
# Đã xử lý chunk 136: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 238
# Tổng số người dùng hiện tại: 220
# Thời gian xử lý chunk: 1.16 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 137 (tổng số reviews đã duyệt: 2740000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 138 (tổng số reviews đã duyệt: 2760000)...
# Đã xử lý chunk 138: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 239
# Tổng số người dùng hiện tại: 221
# Thời gian xử lý chunk: 1.10 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 139 (tổng số reviews đã duyệt: 2780000)...
# Đã xử lý chunk 139: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 242
# Tổng số người dùng hiện tại: 224
# Thời gian xử lý chunk: 1.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 140 (tổng số reviews đã duyệt: 2800000)...
# Đã xử lý chunk 140: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 243
# Tổng số người dùng hiện tại: 225
# Thời gian xử lý chunk: 1.65 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 141 (tổng số reviews đã duyệt: 2820000)...
# Đã xử lý chunk 141: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 244
# Tổng số người dùng hiện tại: 226
# Thời gian xử lý chunk: 1.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 142 (tổng số reviews đã duyệt: 2840000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 143 (tổng số reviews đã duyệt: 2860000)...
# Đã xử lý chunk 143: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 246
# Tổng số người dùng hiện tại: 228
# Thời gian xử lý chunk: 1.61 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 144 (tổng số reviews đã duyệt: 2880000)...
# Đã xử lý chunk 144: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 247
# Tổng số người dùng hiện tại: 229
# Thời gian xử lý chunk: 2.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 145 (tổng số reviews đã duyệt: 2900000)...
# Đã xử lý chunk 145: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 248
# Tổng số người dùng hiện tại: 230
# Thời gian xử lý chunk: 1.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 146 (tổng số reviews đã duyệt: 2920000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 147 (tổng số reviews đã duyệt: 2940000)...
# Đã xử lý chunk 147: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 249
# Tổng số người dùng hiện tại: 231
# Thời gian xử lý chunk: 2.54 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 148 (tổng số reviews đã duyệt: 2960000)...
# Đã xử lý chunk 148: 2 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 251
# Tổng số người dùng hiện tại: 232
# Thời gian xử lý chunk: 3.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 149 (tổng số reviews đã duyệt: 2980000)...
# Đã xử lý chunk 149: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 253
# Tổng số người dùng hiện tại: 234
# Thời gian xử lý chunk: 2.77 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 150 (tổng số reviews đã duyệt: 3000000)...
# Đã xử lý chunk 150: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 255
# Tổng số người dùng hiện tại: 236
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 151 (tổng số reviews đã duyệt: 3020000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 152 (tổng số reviews đã duyệt: 3040000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 153 (tổng số reviews đã duyệt: 3060000)...
# Đã xử lý chunk 153: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 256
# Tổng số người dùng hiện tại: 237
# Thời gian xử lý chunk: 1.64 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 154 (tổng số reviews đã duyệt: 3080000)...
# Đã xử lý chunk 154: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 257
# Tổng số người dùng hiện tại: 238
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 155 (tổng số reviews đã duyệt: 3100000)...
# Đã xử lý chunk 155: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 261
# Tổng số người dùng hiện tại: 242
# Thời gian xử lý chunk: 1.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 156 (tổng số reviews đã duyệt: 3120000)...
# Đã xử lý chunk 156: 6 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 267
# Tổng số người dùng hiện tại: 247
# Thời gian xử lý chunk: 1.45 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 157 (tổng số reviews đã duyệt: 3140000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 158 (tổng số reviews đã duyệt: 3160000)...
# Đã xử lý chunk 158: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 268
# Tổng số người dùng hiện tại: 248
# Thời gian xử lý chunk: 1.36 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 159 (tổng số reviews đã duyệt: 3180000)...
# Đã xử lý chunk 159: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 270
# Tổng số người dùng hiện tại: 250
# Thời gian xử lý chunk: 1.12 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 160 (tổng số reviews đã duyệt: 3200000)...
# Đã xử lý chunk 160: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 271
# Tổng số người dùng hiện tại: 251
# Thời gian xử lý chunk: 1.10 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 161 (tổng số reviews đã duyệt: 3220000)...
# Đã xử lý chunk 161: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 272
# Tổng số người dùng hiện tại: 252
# Thời gian xử lý chunk: 1.57 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 162 (tổng số reviews đã duyệt: 3240000)...
# Đã xử lý chunk 162: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 274
# Tổng số người dùng hiện tại: 254
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 163 (tổng số reviews đã duyệt: 3260000)...
# Đã xử lý chunk 163: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 276
# Tổng số người dùng hiện tại: 256
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 164 (tổng số reviews đã duyệt: 3280000)...
# Đã xử lý chunk 164: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 277
# Tổng số người dùng hiện tại: 257
# Thời gian xử lý chunk: 1.06 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 165 (tổng số reviews đã duyệt: 3300000)...
# Đã xử lý chunk 165: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 278
# Tổng số người dùng hiện tại: 258
# Thời gian xử lý chunk: 1.22 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 166 (tổng số reviews đã duyệt: 3320000)...
# Đã xử lý chunk 166: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 279
# Tổng số người dùng hiện tại: 259
# Thời gian xử lý chunk: 1.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 167 (tổng số reviews đã duyệt: 3340000)...
# Đã xử lý chunk 167: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 280
# Tổng số người dùng hiện tại: 260
# Thời gian xử lý chunk: 1.62 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 168 (tổng số reviews đã duyệt: 3360000)...
# Đã xử lý chunk 168: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 281
# Tổng số người dùng hiện tại: 261
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 169 (tổng số reviews đã duyệt: 3380000)...
# Đã xử lý chunk 169: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 283
# Tổng số người dùng hiện tại: 263
# Thời gian xử lý chunk: 1.17 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 170 (tổng số reviews đã duyệt: 3400000)...
# Đã xử lý chunk 170: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 286
# Tổng số người dùng hiện tại: 266
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 171 (tổng số reviews đã duyệt: 3420000)...
# Đã xử lý chunk 171: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 288
# Tổng số người dùng hiện tại: 268
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 172 (tổng số reviews đã duyệt: 3440000)...
# Đã xử lý chunk 172: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 292
# Tổng số người dùng hiện tại: 272
# Thời gian xử lý chunk: 1.06 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 173 (tổng số reviews đã duyệt: 3460000)...
# Đã xử lý chunk 173: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 295
# Tổng số người dùng hiện tại: 275
# Thời gian xử lý chunk: 1.66 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 174 (tổng số reviews đã duyệt: 3480000)...
# Đã xử lý chunk 174: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 296
# Tổng số người dùng hiện tại: 276
# Thời gian xử lý chunk: 1.31 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 175 (tổng số reviews đã duyệt: 3500000)...
# Đã xử lý chunk 175: 6 đánh giá hợp lệ, 6 người dùng mới được thêm
# Tổng số reviews đã xử lý: 302
# Tổng số người dùng hiện tại: 282
# Thời gian xử lý chunk: 1.29 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 176 (tổng số reviews đã duyệt: 3520000)...
# Đã xử lý chunk 176: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 304
# Tổng số người dùng hiện tại: 284
# Thời gian xử lý chunk: 1.56 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 177 (tổng số reviews đã duyệt: 3540000)...
# Đã xử lý chunk 177: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 307
# Tổng số người dùng hiện tại: 287
# Thời gian xử lý chunk: 2.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 178 (tổng số reviews đã duyệt: 3560000)...
# Đã xử lý chunk 178: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 308
# Tổng số người dùng hiện tại: 288
# Thời gian xử lý chunk: 1.08 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 179 (tổng số reviews đã duyệt: 3580000)...
# Đã xử lý chunk 179: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 311
# Tổng số người dùng hiện tại: 291
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 180 (tổng số reviews đã duyệt: 3600000)...
# Đã xử lý chunk 180: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 313
# Tổng số người dùng hiện tại: 293
# Thời gian xử lý chunk: 1.99 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 181 (tổng số reviews đã duyệt: 3620000)...
# Đã xử lý chunk 181: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 314
# Tổng số người dùng hiện tại: 294
# Thời gian xử lý chunk: 1.18 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 182 (tổng số reviews đã duyệt: 3640000)...
# Đã xử lý chunk 182: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 316
# Tổng số người dùng hiện tại: 296
# Thời gian xử lý chunk: 1.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 183 (tổng số reviews đã duyệt: 3660000)...
# Đã xử lý chunk 183: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 317
# Tổng số người dùng hiện tại: 297
# Thời gian xử lý chunk: 0.59 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 184 (tổng số reviews đã duyệt: 3680000)...
# Đã xử lý chunk 184: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 318
# Tổng số người dùng hiện tại: 298
# Thời gian xử lý chunk: 1.07 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 185 (tổng số reviews đã duyệt: 3700000)...
# Đã xử lý chunk 185: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 321
# Tổng số người dùng hiện tại: 301
# Thời gian xử lý chunk: 1.76 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 186 (tổng số reviews đã duyệt: 3720000)...
# Đã xử lý chunk 186: 7 đánh giá hợp lệ, 7 người dùng mới được thêm
# Tổng số reviews đã xử lý: 328
# Tổng số người dùng hiện tại: 308
# Thời gian xử lý chunk: 2.26 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 187 (tổng số reviews đã duyệt: 3740000)...
# Đã xử lý chunk 187: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 329
# Tổng số người dùng hiện tại: 309
# Thời gian xử lý chunk: 1.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 188 (tổng số reviews đã duyệt: 3760000)...
# Đã xử lý chunk 188: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 331
# Tổng số người dùng hiện tại: 311
# Thời gian xử lý chunk: 1.23 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 189 (tổng số reviews đã duyệt: 3780000)...
# Đã xử lý chunk 189: 4 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 335
# Tổng số người dùng hiện tại: 314
# Thời gian xử lý chunk: 2.35 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 190 (tổng số reviews đã duyệt: 3800000)...
# Đã xử lý chunk 190: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 337
# Tổng số người dùng hiện tại: 316
# Thời gian xử lý chunk: 1.10 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 191 (tổng số reviews đã duyệt: 3820000)...
# Đã xử lý chunk 191: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 338
# Tổng số người dùng hiện tại: 317
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 192 (tổng số reviews đã duyệt: 3840000)...
# Đã xử lý chunk 192: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# ...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 1417 (tổng số reviews đã duyệt: 28340000)...
# Đã xử lý chunk 1417: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3456
# Tổng số người dùng hiện tại: 3284
# Thời gian xử lý chunk: 1.48 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1418 (tổng số reviews đã duyệt: 28360000)...
# Đã xử lý chunk 1418: 8 đánh giá hợp lệ, 8 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3464
# Tổng số người dùng hiện tại: 3292
# Thời gian xử lý chunk: 1.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1419 (tổng số reviews đã duyệt: 28380000)...
# Đã xử lý chunk 1419: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3467
# Tổng số người dùng hiện tại: 3295
# Thời gian xử lý chunk: 1.66 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1420 (tổng số reviews đã duyệt: 28400000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 1421 (tổng số reviews đã duyệt: 28420000)...
# Đã xử lý chunk 1421: 8 đánh giá hợp lệ, 8 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3475
# Tổng số người dùng hiện tại: 3303
# Thời gian xử lý chunk: 1.71 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1422 (tổng số reviews đã duyệt: 28440000)...
# Đã xử lý chunk 1422: 7 đánh giá hợp lệ, 7 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3482
# Tổng số người dùng hiện tại: 3310
# Thời gian xử lý chunk: 1.12 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1423 (tổng số reviews đã duyệt: 28460000)...
# Đã xử lý chunk 1423: 5 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3487
# Tổng số người dùng hiện tại: 3315
# Thời gian xử lý chunk: 2.02 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1424 (tổng số reviews đã duyệt: 28480000)...
# Đã xử lý chunk 1424: 45 đánh giá hợp lệ, 44 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3532
# Tổng số người dùng hiện tại: 3359
# Thời gian xử lý chunk: 1.66 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1425 (tổng số reviews đã duyệt: 28500000)...
# Đã xử lý chunk 1425: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3533
# Tổng số người dùng hiện tại: 3360
# Thời gian xử lý chunk: 1.10 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1426 (tổng số reviews đã duyệt: 28520000)...
# Đã xử lý chunk 1426: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3537
# Tổng số người dùng hiện tại: 3364
# Thời gian xử lý chunk: 1.67 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1427 (tổng số reviews đã duyệt: 28540000)...
# Đã xử lý chunk 1427: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3538
# Tổng số người dùng hiện tại: 3365
# Thời gian xử lý chunk: 1.09 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1428 (tổng số reviews đã duyệt: 28560000)...
# Đã xử lý chunk 1428: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3541
# Tổng số người dùng hiện tại: 3368
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1429 (tổng số reviews đã duyệt: 28580000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 1430 (tổng số reviews đã duyệt: 28600000)...
# Đã xử lý chunk 1430: 6 đánh giá hợp lệ, 6 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3547
# Tổng số người dùng hiện tại: 3374
# Thời gian xử lý chunk: 1.10 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1431 (tổng số reviews đã duyệt: 28620000)...
# Đã xử lý chunk 1431: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3548
# Tổng số người dùng hiện tại: 3375
# Thời gian xử lý chunk: 2.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1432 (tổng số reviews đã duyệt: 28640000)...
# Đã xử lý chunk 1432: 16 đánh giá hợp lệ, 15 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3564
# Tổng số người dùng hiện tại: 3390
# Thời gian xử lý chunk: 1.05 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1433 (tổng số reviews đã duyệt: 28660000)...
# Đã xử lý chunk 1433: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3566
# Tổng số người dùng hiện tại: 3392
# Thời gian xử lý chunk: 2.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1434 (tổng số reviews đã duyệt: 28680000)...
# Đã xử lý chunk 1434: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3567
# Tổng số người dùng hiện tại: 3393
# Thời gian xử lý chunk: 1.30 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1435 (tổng số reviews đã duyệt: 28700000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 1436 (tổng số reviews đã duyệt: 28720000)...
# Đã xử lý chunk 1436: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3569
# Tổng số người dùng hiện tại: 3395
# Thời gian xử lý chunk: 1.35 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1437 (tổng số reviews đã duyệt: 28740000)...
# Đã xử lý chunk 1437: 15 đánh giá hợp lệ, 14 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3584
# Tổng số người dùng hiện tại: 3409
# Thời gian xử lý chunk: 1.12 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1438 (tổng số reviews đã duyệt: 28760000)...
# Đã xử lý chunk 1438: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3585
# Tổng số người dùng hiện tại: 3410
# Thời gian xử lý chunk: 1.89 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1439 (tổng số reviews đã duyệt: 28780000)...
# Đã xử lý chunk 1439: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3587
# Tổng số người dùng hiện tại: 3412
# Thời gian xử lý chunk: 1.11 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1440 (tổng số reviews đã duyệt: 28800000)...
# Đã xử lý chunk 1440: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3591
# Tổng số người dùng hiện tại: 3416
# Thời gian xử lý chunk: 1.67 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1441 (tổng số reviews đã duyệt: 28820000)...
# Đã xử lý chunk 1441: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3595
# Tổng số người dùng hiện tại: 3420
# Thời gian xử lý chunk: 1.32 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1442 (tổng số reviews đã duyệt: 28840000)...
# Đã xử lý chunk 1442: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3596
# Tổng số người dùng hiện tại: 3421
# Thời gian xử lý chunk: 1.17 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1443 (tổng số reviews đã duyệt: 28860000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 1444 (tổng số reviews đã duyệt: 28880000)...
# Đã xử lý chunk 1444: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3600
# Tổng số người dùng hiện tại: 3425
# Thời gian xử lý chunk: 1.68 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1445 (tổng số reviews đã duyệt: 28900000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 1446 (tổng số reviews đã duyệt: 28920000)...
# Đã xử lý chunk 1446: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3601
# Tổng số người dùng hiện tại: 3426
# Thời gian xử lý chunk: 1.37 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1447 (tổng số reviews đã duyệt: 28940000)...
# Đã xử lý chunk 1447: 6 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3607
# Tổng số người dùng hiện tại: 3431
# Thời gian xử lý chunk: 1.62 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1448 (tổng số reviews đã duyệt: 28960000)...
# Đã xử lý chunk 1448: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3608
# Tổng số người dùng hiện tại: 3432
# Thời gian xử lý chunk: 2.60 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1449 (tổng số reviews đã duyệt: 28980000)...
# Đã xử lý chunk 1449: 2 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3610
# Tổng số người dùng hiện tại: 3433
# Thời gian xử lý chunk: 1.45 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1450 (tổng số reviews đã duyệt: 29000000)...
# Đã xử lý chunk 1450: 3 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3613
# Tổng số người dùng hiện tại: 3435
# Thời gian xử lý chunk: 1.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1451 (tổng số reviews đã duyệt: 29020000)...
# Đã xử lý chunk 1451: 6 đánh giá hợp lệ, 6 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3619
# Tổng số người dùng hiện tại: 3441
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1452 (tổng số reviews đã duyệt: 29040000)...
# Đã xử lý chunk 1452: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3622
# Tổng số người dùng hiện tại: 3444
# Thời gian xử lý chunk: 2.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1453 (tổng số reviews đã duyệt: 29060000)...
# Đã xử lý chunk 1453: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3623
# Tổng số người dùng hiện tại: 3445
# Thời gian xử lý chunk: 1.40 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1454 (tổng số reviews đã duyệt: 29080000)...
# Đã xử lý chunk 1454: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3624
# Tổng số người dùng hiện tại: 3446
# Thời gian xử lý chunk: 1.63 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1455 (tổng số reviews đã duyệt: 29100000)...
# Đã xử lý chunk 1455: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3625
# Tổng số người dùng hiện tại: 3447
# Thời gian xử lý chunk: 1.92 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1456 (tổng số reviews đã duyệt: 29120000)...
# Chunk rỗng, tiếp tục...
#
# Bắt đầu xử lý chunk 1457 (tổng số reviews đã duyệt: 29140000)...
# Đã xử lý chunk 1457: 3 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3628
# Tổng số người dùng hiện tại: 3449
# Thời gian xử lý chunk: 1.71 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1458 (tổng số reviews đã duyệt: 29160000)...
# Đã xử lý chunk 1458: 14 đánh giá hợp lệ, 12 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3642
# Tổng số người dùng hiện tại: 3461
# Thời gian xử lý chunk: 1.09 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1459 (tổng số reviews đã duyệt: 29180000)...
# Đã xử lý chunk 1459: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3643
# Tổng số người dùng hiện tại: 3462
# Thời gian xử lý chunk: 1.66 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1460 (tổng số reviews đã duyệt: 29200000)...
# Đã xử lý chunk 1460: 10 đánh giá hợp lệ, 10 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3653
# Tổng số người dùng hiện tại: 3472
# Thời gian xử lý chunk: 1.80 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1461 (tổng số reviews đã duyệt: 29220000)...
# Đã xử lý chunk 1461: 7 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3660
# Tổng số người dùng hiện tại: 3477
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1462 (tổng số reviews đã duyệt: 29240000)...
# Đã xử lý chunk 1462: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3663
# Tổng số người dùng hiện tại: 3480
# Thời gian xử lý chunk: 1.13 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1463 (tổng số reviews đã duyệt: 29260000)...
# Đã xử lý chunk 1463: 8 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3671
# Tổng số người dùng hiện tại: 3485
# Thời gian xử lý chunk: 1.58 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1464 (tổng số reviews đã duyệt: 29280000)...
# Đã xử lý chunk 1464: 12 đánh giá hợp lệ, 8 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3683
# Tổng số người dùng hiện tại: 3493
# Thời gian xử lý chunk: 1.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1465 (tổng số reviews đã duyệt: 29300000)...
# Đã xử lý chunk 1465: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3685
# Tổng số người dùng hiện tại: 3495
# Thời gian xử lý chunk: 1.73 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1466 (tổng số reviews đã duyệt: 29320000)...
# Đã xử lý chunk 1466: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3686
# Tổng số người dùng hiện tại: 3496
# Thời gian xử lý chunk: 1.15 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1467 (tổng số reviews đã duyệt: 29340000)...
# Đã xử lý chunk 1467: 4 đánh giá hợp lệ, 4 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3690
# Tổng số người dùng hiện tại: 3500
# Thời gian xử lý chunk: 1.55 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1468 (tổng số reviews đã duyệt: 29360000)...
# Đã xử lý chunk 1468: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3693
# Tổng số người dùng hiện tại: 3503
# Thời gian xử lý chunk: 1.14 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1469 (tổng số reviews đã duyệt: 29380000)...
# Đã xử lý chunk 1469: 1 đánh giá hợp lệ, 1 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3694
# Tổng số người dùng hiện tại: 3504
# Thời gian xử lý chunk: 1.25 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1470 (tổng số reviews đã duyệt: 29400000)...
# Đã xử lý chunk 1470: 5 đánh giá hợp lệ, 5 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3699
# Tổng số người dùng hiện tại: 3509
# Thời gian xử lý chunk: 1.69 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1471 (tổng số reviews đã duyệt: 29420000)...
# Đã xử lý chunk 1471: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3701
# Tổng số người dùng hiện tại: 3511
# Thời gian xử lý chunk: 1.42 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1472 (tổng số reviews đã duyệt: 29440000)...
# Đã xử lý chunk 1472: 2 đánh giá hợp lệ, 2 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3703
# Tổng số người dùng hiện tại: 3513
# Thời gian xử lý chunk: 4.12 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Bắt đầu xử lý chunk 1473 (tổng số reviews đã duyệt: 29460000)...
# Đã xử lý chunk 1473: 3 đánh giá hợp lệ, 3 người dùng mới được thêm
# Tổng số reviews đã xử lý: 3706
# Tổng số người dùng hiện tại: 3516
# Thời gian xử lý chunk: 1.34 giây
# Đã lưu checkpoint tại C:\Users\thait\LABS\NC\cit-meta\checkpoint.json
#
# Hoàn tất quá trình xử lý! Tổng thời gian: 39.99 phút

# %%
# tạo dataframe content chứa dữ liệu cho gợi ý dựa trên thể loại
from home.models import Book_Topic, Book
from home.models import ContentBook
import pandas as pd
books = Book.objects.all().order_by('book_id')
bookTopic = Book_Topic.objects.prefetch_related('topic_id').order_by('book_id')
check = True
dics = []
for book in books:
    content = book.book_title
    topics = bookTopic.filter(book_id = book.book_id)
    for topic in topics:
        content+=' '+topic.topic_id.topic_name
    dic = {'book_id': book.book_id,
            'content': content
           }
    dics.append(dic) 
book_df = pd.DataFrame(dics)
print(book_df)
# Out:
#     book_id                                            content
# 0      3001  CDMA capacity and quality optimization code di...
# 1      3002  Image databases : Search and retrieval of digi...
# 2      3003  Practical handbook on image processing for sci...
# 3      3004  Analytics, data science, & artificial intellig...
# 4      3005  Composing cyberspace : Identity, community, an...
# ..      ...                                                ...
# 74     3075  Digital image processing Image processing Digi...
# 75     3076  Digital image processing using MATLAB Image pr...
# 76     3078  Database systems the complete book Database de...
# 77     3080  Data structures and abstractions with Java Jav...
# 78     3081  MySQL/PHP database applications database appli...
#
# [79 rows x 2 columns]

# %%
from home.models import ContentBook
import pandas as pd
bookContent = ContentBook.objects.all().order_by('book_id')
dics = []
for book in bookContent:
    dic = {
        'book_id': book.book_id,
        'content': book.content
    }
    dics.append(dic)
book_df = pd.DataFrame(dics)
print(book_df)
# Out:
#     book_id                                            content
# 0      3001  CDMA capacity and quality optimization code di...
# 1      3002  Image databases : Search and retrieval of digi...
# 2      3003  Practical handbook on image processing for sci...
# 3      3004  Analytics, data science, & artificial intellig...
# 4      3005  Composing cyberspace : Identity, community, an...
# ..      ...                                                ...
# 74     3075  Digital image processing Image processing Digi...
# 75     3076  Digital image processing using MATLAB Image pr...
# 76     3078  Database systems the complete book Database de...
# 77     3080  Data structures and abstractions with Java App...
# 78     3081  MySQL/PHP database applications Database desig...
#
# [79 rows x 2 columns]

# %%
import pickle

# Lưu TF-IDF Vectorizer
with open('./home/recommend/book_tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(book_tfidf, f)

with open('./home/recommend/book_cosine_similarity.pkl', 'wb') as f:
    pickle.dump(cosine_similarity, f)

# %%
from home.models import ContentBook
import pickle
with open('./home/recommend/book_tfidf_vectorizer.pkl', 'rb') as f:
    book_tfidf = pickle.load(f)
bookContents = ContentBook.objects.all().order_by('book_id')
book_df = pd.DataFrame(bookContents)   
book_content_matrix = book_tfidf.fit_transform(book_df['content'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 7
#       5 bookContents = ContentBook.objects.all().order_by('book_id')
#       6 book_df = pd.DataFrame(bookContents)
# ----> 7 book_content_matrix = book_tfidf.fit_transform(book_df['content'])
#
# File c:\Users\thait\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\thait\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'content'

# %%
# Thao tac tinh toan va dua ra goi y
choice = 67
similarity_scores = list(enumerate(cosine_similarity[choice-1]))
similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
similarity_scores = similarity_scores[1:6]

# Get the similar books index
books_index = [i[0] for i in similarity_scores]
books = Book.objects.all().order_by('book_id')
# printing the top 5 most similar books using integer-location based indexing (iloc)
print(f'The choice is: {books[choice-1].book_id} {books[choice-1].book_title}')
for i in books_index:
    print(f'{books[i].book_id} - {books[i].book_title} ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Thao tac tinh toan va dua ra goi y
#       2 choice = 67
# ----> 3 similarity_scores = list(enumerate(cosine_similarity[choice-1]))
#       4 similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
#       5 similarity_scores = similarity_scores[1:6]
#
# NameError: name 'cosine_similarity' is not defined

# %%
# Giả sử bạn có dữ liệu về sách mới
new_books_df['content'] = new_books_df['content'].fillna('')

# Vector hóa nội dung sách mới
new_book_content_matrix = book_tfidf.transform(new_books_df['content'])

# Cập nhật ma trận cosine similarity
new_cosine_similarity = linear_kernel(new_book_content_matrix, book_content_matrix)

# Gộp ma trận cũ và mới lại để cập nhật toàn bộ hệ thống
cosine_similarity = linear_kernel(book_content_matrix, book_content_matrix)

# Lưu lại các dữ liệu đã cập nhật
with open('book_tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(book_tfidf, f)

with open('book_cosine_similarity.pkl', 'wb') as f:
    pickle.dump(cosine_similarity, f)

# %%
from django_for_jupyter import init_django
init_django()

# %%
from home.models import ContentBook, Book, Book_Topic
import pandas as pd
latest_book = Book.objects.latest('book_id')
content = latest_book.book_title
topics = Book_Topic.objects.filter(book_id=latest_book.book_id).select_related('topic_id')
for topic in topics:
    content+=' '+ topic.topic_id.topic_name
print(content)
# newContent = ContentBook(book = latest_book, content = content)
# newContent.save()
newContentDic ={
    'book_id': latest_book.book_id,
    'content': content
}
newContent_df = pd.DataFrame(newContentDic, index=[0])
print(newContent_df['content'][0])
# Out:
# Database systems the complete book Database design (Thiết kế database) Database management (Quản trị database)
# Database systems the complete book Database design (Thiết kế database) Database management (Quản trị database)

# %%
from home.models import ContentBook
from sklearn.metrics.pairwise import linear_kernel
import pickle
import pandas as pd
    
    
with open('./home/recommend/book_tfidf_vectorizer.pkl', 'rb') as f:
    book_tfidf = pickle.load(f)

bookContents = ContentBook.objects.all().order_by('book_id').values('book_id', 'content')
book_df = pd.DataFrame(bookContents)
book_df['content'] = book_df['content'].fillna('')
book_df['content'] = book_df['content'].astype(str)

    
book_content_matrix = book_tfidf.fit_transform(book_df['content']) 
    
cosine_similarity = linear_kernel(book_content_matrix, book_content_matrix)
print(enumerate(cosine_similarity))
# Out:
# <enumerate object at 0x000001F519857790>

# %%
from home.models import ContentBook
import pickle
import pandas as pd


bookContents = ContentBook.objects.all().order_by('book_id').values('book_id')
book_df = pd.DataFrame(bookContents)
book_id = 3032
book_df.set_index('book_id', inplace=True)
print(book_df)
book_index = book_df.index.get_loc(book_id)
print(book_index)
with open('./home/recommend/book_cosine_similarity.pkl', 'rb') as f:
    cosine_similarity = pickle.load(f)
# Out:
# Empty DataFrame
# Columns: []
# Index: [3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013, 3014, 3015, 3016, 3017, 3018, 3019, 3020, 3021, 3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035, 3036, 3037, 3038, 3039, 3040, 3041, 3042, 3043, 3044, 3045, 3046, 3047, 3048, 3049, 3050, 3051, 3052, 3053, 3054, 3055, 3056, 3057, 3058, 3059, 3060, 3061, 3062, 3063, 3064, 3065, 3066, 3067, 3068, 3069, 3070, 3071, 3072, 3073, 3074, 3075, 3076, 3078, 3079, 3080, 3081]
#
# [80 rows x 0 columns]
# 31

# %%
from home.models import ContentBook
import pandas as pd
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text

books = ContentBook.objects.all().order_by('book_id').values('book_id', 'content')
book_df = pd.DataFrame(books)
book_df['content'] = book_df['content'].fillna('')

enlish_stop_words = text.ENGLISH_STOP_WORDS
vietnamese_stop_words = ["và", "là", "của", "những", "với", "từ", "một", "được", "khi", "đã", "cho", "vì", "ở", "này", "giáo", "trình", "lập", "trình"]
combine_stop_words = list(enlish_stop_words) + vietnamese_stop_words
book_tfidf = TfidfVectorizer(stop_words=combine_stop_words)
book_content_matrix = book_tfidf.fit_transform(book_df['content']) 

cosine_similarities = linear_kernel(book_content_matrix, book_content_matrix)

# %%
# Thao tac tinh toan va dua ra goi y


choice = book_index
similarity_scores = list(enumerate(cosine_similarity[choice]))
similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
similarity_scores = similarity_scores[2:7]

# Get the similar books index
books_index = [i[0] for i in similarity_scores]
from home.models import Book
books = Book.objects.all().order_by('book_id')
# printing the top 5 most similar books using integer-location based indexing (iloc)
print(f'The choice is: {books[choice].book_id} {books[choice].book_title}')
for i in books_index:
    print(f'{books[i].book_id} - {books[i].book_title} ')
# Out:
# The choice is: 3032 Cisco The complete reference
# 3045 - Giáo trình mạng máy tính
# 3013 - Data communications, computer networks and open systems
# 3062 - Giáo trình quản trị hệ thống mạng
# 3064 - Giáo trình các hệ thống phân tán
# 3031 - The complete reference Java 2
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# ham update content book khi update bôok
# lay ra title, topics của cuốn sách mới nhất được cập nhật thông qua created_at
# chạy lại vòng lặp topic và cập nhật content dựa vào book_id
from home.models import ContentBook, Book, Book_Topic
import pandas as pd
lasted_update = Book.objects.latest('created_at')

content = lasted_update.book_title
content = str(content)
topics = Book_Topic.objects.filter(book_id_id = lasted_update.book_id).select_related('topic_id')
for topic in topics:
    print(str(topic.topic_id.topic_name))
    content+=' '+ str(topic.topic_id.topic_name)
    print(content)
content_update = ContentBook.objects.get(book_id = lasted_update.book_id)
content_update.content = content
content_update.save()

updateContentDic = {
    'book_id': lasted_update.book_id,
    'content': content
}
updateContent_df = pd.DataFrame(updateContentDic, index=[0])
print(updateContent_df)
# Out:
# Data structure (cấu trúc dữ liệu)
# Perl database programming Data structure (cấu trúc dữ liệu)
# Database structure
# Perl database programming Data structure (cấu trúc dữ liệu) Database structure
#    book_id                                            content
# 0     3079  Perl database programming Data structure (cấu ...

# %%
from home.models import Book
book_id = 3076
bookList = Book.objects.all().order_by('book_id')
detail = bookList.filter(book_id = book_id).first()
print(type(bookList))
# Out:
# <class 'django.db.models.query.QuerySet'>

# %%
from home.models import FavList, Book
userID = 1
books = FavList.objects.filter(user_id=userID).select_related('book')
bookList = [fav.book for fav in books]
for book in bookList:
    print(book)
# Out:
# 46-Giáo trình kiểm thử phần mềm,Trần, Cao Đệ,Cần Thơ: Nxb. Đại học Cần Thơ, 2012,004.63 / H513,179794,True
# 48-Giáo trình phân tích hệ thống hướng đối tượng,Phạm, Thị Xuân Lộc,Cần Thơ: Nxb. Đại học Cần Thơ, 2014,004.65 / H516,190026,True
# 4-Analytics, data science, & artificial intelligence,Sharda, Ramesh,Harlow, United Kingdom: Pearson, 2021,658.403 / S531,244700,True
